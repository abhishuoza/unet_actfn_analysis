# %% [markdown]
# Author : Aadya Aneesh Chinubhai
#
# Key Steps :
# Build U-Net Class,
# Define Activation function candidates,
# Compare Accuracy & Training time.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Conv2DTranspose, concatenate
from tensorflow.keras.models import Model
from keras import metrics
import keras
import os
import random
from tqdm import tqdm 
from zipfile import ZipFile
from skimage.io import imread, imshow
from skimage.transform import resize
import matplotlib.pyplot as plt
import pandas as pd

# %%
class UNet:
    
    def __init__(self, input_shape_,  activation_ = "relu"):
        self.activation = activation_
        self.input_shape = input_shape_
    
    def dice_coef(self, y_true, y_pred, smooth=100):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)
        
        y_true_f = K.flatten(y_true)
        y_pred_f = K.flatten(y_pred)
        intersection = K.sum(y_true_f * y_pred_f)
        dice = (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
        return dice
    
    def dice_coef_loss(self, y_true, y_pred):
        return -self.dice_coef(y_true, y_pred)
    
    def iou(self, y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)

        def f(y_true, y_pred):
            intersection = (y_true * y_pred).sum()
            union = y_true.sum() + y_pred.sum() - intersection
            x = (intersection + 1e-15) / (union + 1e-15)
            x = x.astype(np.float32)
            return x
        
        return tf.numpy_function(f, [y_true, y_pred], tf.float32)

    def buildModel(self):
        
        # Lets create the DownSampling Blocks 
        kernel_initializer =  'he_uniform'
         
        inputs = tf.keras.Input(shape = self.input_shape)
        
        # Block - 1
    
        s = inputs

        #Contraction path
        c1 = Conv2D(16, (3, 3), activation= self.activation, kernel_initializer=kernel_initializer, padding='same')(s)
#         c1 = Dropout(0.1)(c1)
        c1 = Conv2D(16, (3, 3), activation= self.activation, kernel_initializer=kernel_initializer, padding='same')(c1)
        p1 = MaxPooling2D((2, 2))(c1)

        c2 = Conv2D(32, (3, 3), activation= self.activation, kernel_initializer=kernel_initializer, padding='same')(p1)
#         c2 = Dropout(0.1)(c2)
        c2 = Conv2D(32, (3, 3), activation= self.activation, kernel_initializer=kernel_initializer, padding='same')(c2)
        p2 = MaxPooling2D((2, 2))(c2)

        c3 = Conv2D(64, (3, 3), activation= self.activation, kernel_initializer=kernel_initializer, padding='same')(p2)
#         c3 = Dropout(0.2)(c3)
        c3 = Conv2D(64, (3, 3), activation= self.activation, kernel_initializer=kernel_initializer, padding='same')(c3)
        p3 = MaxPooling2D((2, 2))(c3)

        c4 = Conv2D(128, (3, 3), activation= self.activation, kernel_initializer=kernel_initializer, padding='same')(p3)
#         c4 = Dropout(0.2)(c4)
        c4 = Conv2D(128, (3, 3), activation= self.activation, kernel_initializer=kernel_initializer, padding='same')(c4)
        p4 = MaxPooling2D(pool_size=(2, 2))(c4)

        c5 = Conv2D(256, (3, 3), activation= self.activation, kernel_initializer=kernel_initializer, padding='same')(p4)
#         c5 = Dropout(0.3)(c5)
        c5 = Conv2D(256, (3, 3), activation= self.activation, kernel_initializer=kernel_initializer, padding='same')(c5)

        #Expansive path 
        u6 = Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
        u6 = concatenate([u6, c4])
        c6 = Conv2D(128, (3, 3), activation= self.activation, kernel_initializer=kernel_initializer, padding='same')(u6)
#         c6 = Dropout(0.2)(c6)
        c6 = Conv2D(128, (3, 3), activation= self.activation, kernel_initializer=kernel_initializer, padding='same')(c6)

        u7 = Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c6)
        u7 = concatenate([u7, c3])
        c7 = Conv2D(64, (3, 3), activation= self.activation, kernel_initializer=kernel_initializer, padding='same')(u7)
#         c7 = Dropout(0.2)(c7)
        c7 = Conv2D(64, (3, 3), activation= self.activation, kernel_initializer=kernel_initializer, padding='same')(c7)

        u8 = Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(c7)
        u8 = concatenate([u8, c2])
        c8 = Conv2D(32, (3, 3), activation= self.activation, kernel_initializer=kernel_initializer, padding='same')(u8)
#         c8 = Dropout(0.1)(c8)
        c8 = Conv2D(32, (3, 3), activation= self.activation, kernel_initializer=kernel_initializer, padding='same')(c8)

        u9 = Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(c8)
        u9 = concatenate([u9, c1])
        c9 = Conv2D(16, (3, 3), activation= self.activation, kernel_initializer=kernel_initializer, padding='same')(u9)
#         c9 = Dropout(0.1)(c9)
        c9 = Conv2D(16, (3, 3), activation= self.activation, kernel_initializer=kernel_initializer, padding='same')(c9)

        outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)

        model = Model(inputs=[inputs], outputs=[outputs])
        #compile model outside of this function to make it flexible. 
        model.summary()

        return model
 
    
    def CompileandSummarize(self, model_):
        model_.compile(optimizer = tf.keras.optimizers.Adam(), loss = self.dice_coef_loss, metrics = self.iou)

# %%
'''Defining callbacks to calculate training time '''

from timeit import default_timer as timer

class TimingCallback(keras.callbacks.Callback):
    def __init__(self, logs={}):
        self.logs=[]
    def on_epoch_begin(self, epoch, logs={}):
        self.starttime = timer()
    def on_epoch_end(self, epoch, logs={}):
        self.logs.append(timer()-self.starttime)

# %%
# Now lets focus on preparing the data

with ZipFile("../input/data-science-bowl-2018/stage1_train.zip","r") as zip_ref:
    zip_ref.extractall("./stage1_train")
    
with ZipFile("../input/data-science-bowl-2018/stage1_test.zip","r") as zip_ref:
    zip_ref.extractall("./stage1_test")

# %%
seed = 42
np.random.seed = seed

IMG_WIDTH = 96
IMG_HEIGHT = 96
IMG_CHANNELS = 3

TRAIN_PATH = './stage1_train/'
TEST_PATH = './stage1_test/'

# %%
train_ids = next(os.walk(TRAIN_PATH))[1]
test_ids = next(os.walk(TEST_PATH))[1]

train_ids[:5]
# Out:
# ['337b6eed0726f07531cd467cd62b6676c31a8c9e716bdbc49433986c022252cf',
#  '958114e5f37d5e1420b410bd716753b3e874b175f2b6958ebf1ec2bdf776e41f',
#  '797945873ca2a95f028671714b71eb3f883efe9dae7fcd3fc0ea1521efb73aaa',
#  '358e47eaa1e9222252793fe0fb8c77028d4e0d4360b95a07c9fe6df6a2066556',
#  '8bef203fce625e4d8c89dca728158be4662dfdfdcd4dc73a6aa39a908c1631bc']

# %%
X_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, IMG_CHANNELS), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)

print('Resizing training images and masks')
for n, file_name in tqdm(enumerate(train_ids)):   
    path = TRAIN_PATH + file_name
    img = imread(path + '/images/' + file_name + '.png')[:,:,:IMG_CHANNELS]  
    img = resize(img, (IMG_HEIGHT, IMG_WIDTH), mode='constant', preserve_range=True)
    X_train[n] = img  #Fill empty X_train with values from img
    mask = np.zeros((IMG_HEIGHT, IMG_WIDTH, 1), dtype=np.bool)
    for mask_file in next(os.walk(path + '/masks/'))[2]:
        mask_ = imread(path + '/masks/' + mask_file)
        mask_ = np.expand_dims(resize(mask_, (IMG_HEIGHT, IMG_WIDTH), mode='constant',  
                                      preserve_range=True), axis=-1)
        mask = np.maximum(mask, mask_)  
            
    Y_train[n] = mask
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
# Resizing training images and masks
# 0it [00:00, ?it/s]/opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:10: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   # Remove the CWD from sys.path while we load stuff.
# 670it [04:46,  2.34it/s]

# %%
# 5% Validation Images (34 Images)
X_test, y_test  = X_train[636:], Y_train[636:]
X_train, Y_train = X_train[0: 636], Y_train[0:636]

# %%
(X_train.shape, Y_train.shape), (X_test.shape, y_test.shape)
# Out:
# (((636, 96, 96, 3), (636, 96, 96, 1)), ((34, 96, 96, 3), (34, 96, 96, 1)))

# %%
image_x = random.randint(0, 636)
imshow(X_train[image_x])
plt.show()
imshow(np.squeeze(Y_train[image_x]))
plt.show()

# %%
class MexicanReLU(tf.keras.layers.Layer):
    def __init__(self, alpha=1.0, sigma=1.0, mu=0.0):
        super(MexicanReLU, self).__init__()
        self.alpha = tf.Variable(alpha, trainable=True)
        self.sigma = tf.Variable(sigma, trainable=True)
        self.mu = tf.Variable(mu, trainable=True)

    def call(self, inputs):
        relu = tf.nn.relu(inputs)
        gaussian = self.alpha * tf.exp(-tf.square(inputs - self.mu) / (2 * tf.square(self.sigma))) * (inputs - self.mu)
        return relu + gaussian

# %%
# class SymmetricGaLU(tf.keras.layers.Layer):
#     def __init__(self, **kwargs):
#         super(SymmetricGaLU, self).__init__(**kwargs)

#     def call(self, x):
#         a, b = tf.split(x, 2, axis=-1)
#         return tf.multiply(tf.nn.tanh(a), tf.nn.sigmoid(b))

#     def get_config(self):
#         config = super(SymmetricGaLU, self).get_config()
#         return config

class Gelu(tf.keras.layers.Layer):
    def __init__(self):
        super(Gelu, self).__init__()

    def call(self, inputs):
        cdf = 0.5 * (1.0 + tf.math.erf(inputs / tf.sqrt(2.0)))
        return inputs * cdf

# %%
class Swish(tf.keras.layers.Layer):
    def __init__(self):
        super(Swish, self).__init__()

    def call(self, inputs):
        return inputs * tf.keras.backend.sigmoid(inputs)

# %%
class TrainableLeakyReLU(tf.keras.layers.Layer):
    def __init__(self, alpha_initializer=tf.initializers.constant(0.2), **kwargs):
        super(TrainableLeakyReLU, self).__init__(**kwargs)
        self.alpha_initializer = tf.keras.initializers.get(alpha_initializer)
    
    def build(self, input_shape):
        self.alpha = self.add_weight(shape=(), initializer=self.alpha_initializer, trainable=True, name="alpha")
        super(TrainableLeakyReLU, self).build(input_shape)
    
    def call(self, inputs):
        return tf.maximum(inputs, self.alpha * inputs)
    
    def get_config(self):
        config = super(TrainableLeakyReLU, self).get_config()
        config.update({"alpha_initializer": self.alpha_initializer})
        return config

# %%
class ISRU(tf.keras.layers.Layer):
    def __init__(self, alpha=1.0, **kwargs):
        super(ISRU, self).__init__(**kwargs)
        self.alpha = tf.Variable(initial_value=alpha, trainable=True, name='alpha')

    def call(self, inputs):
        return inputs / tf.sqrt(1.0 + self.alpha * tf.square(inputs))

# %%
class Mish(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(Mish, self).__init__(**kwargs)

    def call(self, inputs):
        return inputs * tf.math.tanh(tf.math.softplus(inputs))

# %%
from tensorflow.keras.layers import Layer

class gated_swish(Layer):
    
    def __init__(self):
        super(gated_swish, self).__init__()

    def call(self, inputs):

        """
        Gated Swish activation function.
        """
        gate = tf.math.sigmoid(inputs)
        activation = tf.nn.swish(inputs)
        
        return gate * activation

# %%
class SeLU(tf.keras.layers.Layer):
    def __init__(self, alpha=1.6732632423543772848170429916717, scale=1.0507009873554804934193349852946, **kwargs):
        super().__init__(**kwargs)
        self.alpha = alpha
        self.scale = scale

    def call(self, inputs):
        return self.scale * tf.where(inputs > 0.0, inputs, self.alpha * tf.exp(inputs) - self.alpha)

    def get_config(self):
        config = super().get_config()
        config.update({'alpha': self.alpha, 'scale': self.scale})
        return config

# %%
import tensorflow as tf

class LearnableSwish(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(LearnableSwish, self).__init__(**kwargs)

    def build(self, input_shape):
        self.beta = self.add_weight(shape=(1, ), initializer="ones", trainable=True)
        super(LearnableSwish, self).build(input_shape)

    def call(self, inputs):
        return tf.nn.swish(inputs * self.beta)

# %%
class SRS(tf.keras.layers.Layer):
    def __init__(self, alpha=1.0, **kwargs):
        super(SRS, self).__init__(**kwargs)
        self.alpha = alpha

    def call(self, inputs):
        return tf.maximum(inputs, self.alpha * (tf.sigmoid(inputs) - 0.5))

# %%
class TanELU(tf.keras.layers.Layer):
    def __init__(self, alpha=1.0, **kwargs):
        super(TanELU, self).__init__(**kwargs)
        self.alpha = alpha

    def call(self, inputs):
        pos = tf.nn.relu(inputs)
        neg = self.alpha * (tf.exp(inputs) - 1)
        return tf.where(inputs > 0, tf.tanh(pos), tf.tanh(neg))

# %%
# !mkdir /kaggle/working/logs

# %%
training_inferences={}

# %%
cb = TimingCallback()

UNet_1 = UNet((96, 96, 3), activation_= MexicanReLU())
model1 = UNet_1.buildModel()
UNet_1.CompileandSummarize(model1)
results1 = model1.fit(x = X_train, y = Y_train, batch_size = 8, epochs=150, callbacks = [cb, tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)],  validation_data = (X_test, y_test))

training_inferences['MexicanReLU'] = sum(cb.logs)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 96, 96, 3)]  0           []
#
#  conv2d (Conv2D)                (None, 96, 96, 16)   451         ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 96, 96, 16)   2323        ['conv2d[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 48, 48, 16)   0           ['conv2d_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 48, 48, 32)   4643        ['max_pooling2d[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 48, 48, 32)   9251        ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 24, 24, 32)  0           ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 24, 24, 64)   18499       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 24, 24, 64)   36931       ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 64)  0           ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 12, 12, 128)  73859       ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 12, 12, 128)  147587      ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 6, 6, 128)   0           ['conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 6, 6, 256)    295171      ['max_pooling2d_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 6, 6, 256)    590083      ['conv2d_8[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 12, 12, 128)  131200     ['conv2d_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 12, 12, 256)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 12, 12, 128)  295043      ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 12, 12, 128)  147587      ['conv2d_10[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 24, 24, 64)  32832       ['conv2d_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 24, 24, 128)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 24, 24, 64)   73795       ['concatenate_1[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 24, 24, 64)   36931       ['conv2d_12[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 48, 48, 32)  8224        ['conv2d_13[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 48, 48, 64)   0           ['conv2d_transpose_2[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 48, 48, 32)   18467       ['concatenate_2[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 48, 48, 32)   9251        ['conv2d_14[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 96, 96, 16)  2064        ['conv2d_15[0][0]']
#  spose)
#
#  concatenate_3 (Concatenate)    (None, 96, 96, 32)   0           ['conv2d_transpose_3[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 96, 96, 16)   4627        ['concatenate_3[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 96, 96, 16)   2323        ['conv2d_16[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 96, 96, 1)    17          ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 1,941,108
# Trainable params: 1,941,108
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/150
# 80/80 [==============================] - 12s 31ms/step - loss: -0.7231 - iou: 0.5844 - val_loss: -0.7724 - val_iou: 0.6454
# Epoch 2/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.7964 - iou: 0.6730 - val_loss: -0.8580 - val_iou: 0.7644
# Epoch 3/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.8349 - iou: 0.7248 - val_loss: -0.8953 - val_iou: 0.8173
# Epoch 4/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.8993 - iou: 0.8190 - val_loss: -0.8977 - val_iou: 0.8201
# Epoch 5/150
# 80/80 [==============================] - 2s 22ms/step - loss: -0.9058 - iou: 0.8298 - val_loss: -0.9142 - val_iou: 0.8471
# Epoch 6/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9187 - iou: 0.8512 - val_loss: -0.9122 - val_iou: 0.8449
# Epoch 7/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9135 - iou: 0.8426 - val_loss: -0.9198 - val_iou: 0.8543
# Epoch 8/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9243 - iou: 0.8607 - val_loss: -0.9248 - val_iou: 0.8625
# Epoch 9/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9236 - iou: 0.8592 - val_loss: -0.9231 - val_iou: 0.8580
# Epoch 10/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9283 - iou: 0.8670 - val_loss: -0.9218 - val_iou: 0.8549
# Epoch 11/150
# 80/80 [==============================] - 2s 21ms/step - loss: -0.9290 - iou: 0.8688 - val_loss: -0.9292 - val_iou: 0.8701
# Epoch 12/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9320 - iou: 0.8727 - val_loss: -0.9323 - val_iou: 0.8725
# Epoch 13/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9270 - iou: 0.8653 - val_loss: -0.9266 - val_iou: 0.8636
# Epoch 14/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9345 - iou: 0.8766 - val_loss: -0.9322 - val_iou: 0.8722
# Epoch 15/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9340 - iou: 0.8766 - val_loss: -0.9239 - val_iou: 0.8639
# Epoch 16/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9343 - iou: 0.8770 - val_loss: -0.9321 - val_iou: 0.8723
# Epoch 17/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9353 - iou: 0.8796 - val_loss: -0.9311 - val_iou: 0.8683
# Epoch 18/150
# 80/80 [==============================] - 2s 26ms/step - loss: -0.9353 - iou: 0.8796 - val_loss: -0.9394 - val_iou: 0.8837
# Epoch 19/150
# 80/80 [==============================] - 2s 22ms/step - loss: -0.9357 - iou: 0.8804 - val_loss: -0.9316 - val_iou: 0.8719
# Epoch 20/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9364 - iou: 0.8812 - val_loss: -0.9337 - val_iou: 0.8735
# Epoch 21/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9391 - iou: 0.8857 - val_loss: -0.9388 - val_iou: 0.8823
# Epoch 22/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9398 - iou: 0.8867 - val_loss: -0.9399 - val_iou: 0.8868
# Epoch 23/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9391 - iou: 0.8855 - val_loss: -0.9355 - val_iou: 0.8771
# Epoch 24/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9381 - iou: 0.8846 - val_loss: -0.9422 - val_iou: 0.8874
# Epoch 25/150
# 80/80 [==============================] - 2s 22ms/step - loss: -0.9400 - iou: 0.8880 - val_loss: -0.9374 - val_iou: 0.8782
# Epoch 26/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9401 - iou: 0.8875 - val_loss: -0.9334 - val_iou: 0.8782
# Epoch 27/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9415 - iou: 0.8897 - val_loss: -0.9425 - val_iou: 0.8894
# Epoch 28/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9418 - iou: 0.8904 - val_loss: -0.9395 - val_iou: 0.8863
# Epoch 29/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9433 - iou: 0.8931 - val_loss: -0.9291 - val_iou: 0.8655
# Epoch 30/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9412 - iou: 0.8895 - val_loss: -0.9426 - val_iou: 0.8901
# Epoch 31/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9432 - iou: 0.8927 - val_loss: -0.9410 - val_iou: 0.8865
# Epoch 32/150
# 80/80 [==============================] - 2s 22ms/step - loss: -0.9452 - iou: 0.8966 - val_loss: -0.9447 - val_iou: 0.8936
# Epoch 33/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9449 - iou: 0.8952 - val_loss: -0.9416 - val_iou: 0.8860
# Epoch 34/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9453 - iou: 0.8962 - val_loss: -0.9436 - val_iou: 0.8918
# Epoch 35/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9462 - iou: 0.8962 - val_loss: -0.9441 - val_iou: 0.8935
# Epoch 36/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9456 - iou: 0.8964 - val_loss: -0.9440 - val_iou: 0.8931
# Epoch 37/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9441 - iou: 0.8948 - val_loss: -0.9391 - val_iou: 0.8841
# Epoch 38/150
# 80/80 [==============================] - 2s 25ms/step - loss: -0.9454 - iou: 0.8964 - val_loss: -0.9447 - val_iou: 0.8918
# Epoch 39/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9458 - iou: 0.8974 - val_loss: -0.9449 - val_iou: 0.8921
# Epoch 40/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9452 - iou: 0.8969 - val_loss: -0.9413 - val_iou: 0.8886
# Epoch 41/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9485 - iou: 0.9025 - val_loss: -0.9432 - val_iou: 0.8922
# Epoch 42/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9404 - iou: 0.8881 - val_loss: -0.9407 - val_iou: 0.8865
# Epoch 43/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9476 - iou: 0.9015 - val_loss: -0.9438 - val_iou: 0.8911
# Epoch 44/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9461 - iou: 0.8980 - val_loss: -0.9451 - val_iou: 0.8945
# Epoch 45/150
# 80/80 [==============================] - 2s 21ms/step - loss: -0.9475 - iou: 0.9007 - val_loss: -0.9430 - val_iou: 0.8886
# Epoch 46/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9498 - iou: 0.9048 - val_loss: -0.9444 - val_iou: 0.8926
# Epoch 47/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9488 - iou: 0.9034 - val_loss: -0.9462 - val_iou: 0.8955
# Epoch 48/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9501 - iou: 0.9051 - val_loss: -0.9444 - val_iou: 0.8929
# Epoch 49/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9508 - iou: 0.9062 - val_loss: -0.9410 - val_iou: 0.8860
# Epoch 50/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9492 - iou: 0.9040 - val_loss: -0.9456 - val_iou: 0.8954
# Epoch 51/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9515 - iou: 0.9075 - val_loss: -0.9463 - val_iou: 0.8955
# Epoch 52/150
# 80/80 [==============================] - 2s 21ms/step - loss: -0.9499 - iou: 0.9053 - val_loss: -0.9426 - val_iou: 0.8878
# Epoch 53/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9525 - iou: 0.9093 - val_loss: -0.9451 - val_iou: 0.8941
# Epoch 54/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9509 - iou: 0.9073 - val_loss: -0.9460 - val_iou: 0.8975
# Epoch 55/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9532 - iou: 0.9113 - val_loss: -0.9456 - val_iou: 0.8940
# Epoch 56/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9522 - iou: 0.9095 - val_loss: -0.9478 - val_iou: 0.8997
# Epoch 57/150
# 80/80 [==============================] - 2s 21ms/step - loss: -0.9525 - iou: 0.9099 - val_loss: -0.9469 - val_iou: 0.8985
# Epoch 58/150
# 80/80 [==============================] - 2s 22ms/step - loss: -0.9519 - iou: 0.9084 - val_loss: -0.9441 - val_iou: 0.8929
# Epoch 59/150
# 80/80 [==============================] - 2s 22ms/step - loss: -0.9526 - iou: 0.9106 - val_loss: -0.9466 - val_iou: 0.8992
# Epoch 60/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9554 - iou: 0.9147 - val_loss: -0.9478 - val_iou: 0.8990
# Epoch 61/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9510 - iou: 0.9069 - val_loss: -0.9489 - val_iou: 0.9008
# Epoch 62/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9538 - iou: 0.9124 - val_loss: -0.9448 - val_iou: 0.8944
# Epoch 63/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9553 - iou: 0.9146 - val_loss: -0.9458 - val_iou: 0.8953
# Epoch 64/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9533 - iou: 0.9111 - val_loss: -0.9455 - val_iou: 0.8918
# Epoch 65/150
# 80/80 [==============================] - 2s 21ms/step - loss: -0.9540 - iou: 0.9119 - val_loss: -0.9470 - val_iou: 0.8967
# Epoch 66/150
# 80/80 [==============================] - 2s 21ms/step - loss: -0.9526 - iou: 0.9098 - val_loss: -0.9430 - val_iou: 0.8917
# Epoch 67/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9514 - iou: 0.9069 - val_loss: -0.9406 - val_iou: 0.8852
# Epoch 68/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9494 - iou: 0.9041 - val_loss: -0.9464 - val_iou: 0.8985
# Epoch 69/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9542 - iou: 0.9124 - val_loss: -0.9476 - val_iou: 0.8990
# Epoch 70/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9551 - iou: 0.9137 - val_loss: -0.9458 - val_iou: 0.8940
# Epoch 71/150
# 80/80 [==============================] - 2s 20ms/step - loss: -0.9557 - iou: 0.9152 - val_loss: -0.9450 - val_iou: 0.8945

# %%
plt.plot(results1.history['val_loss'])

# %%
plt.plot(results1.history['val_iou'])

# %%
plt.plot(results1.history['loss'])

# %%
plt.plot(results1.history['iou'])

# %%
training_inferences
# Out:
# {'MexicanReLU': 125.468850857}

# %%
cb = TimingCallback()

UNet_2 = UNet((96, 96, 3), activation_= Swish())
model2 = UNet_2.buildModel()
UNet_2.CompileandSummarize(model2)
results2 = model2.fit(x = X_train, y = Y_train, batch_size = 8, epochs=150, callbacks = [cb, tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)],  validation_data = (X_test, y_test))

training_inferences['Swish'] = sum(cb.logs)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 96, 96, 3)]  0           []
#
#  conv2d_19 (Conv2D)             (None, 96, 96, 16)   448         ['input_2[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 96, 96, 16)   2320        ['conv2d_19[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 48, 48, 16)  0           ['conv2d_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 48, 48, 32)   4640        ['max_pooling2d_4[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 48, 48, 32)   9248        ['conv2d_21[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 24, 24, 32)  0           ['conv2d_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 24, 24, 64)   18496       ['max_pooling2d_5[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 24, 24, 64)   36928       ['conv2d_23[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 12, 12, 64)  0           ['conv2d_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 12, 12, 128)  73856       ['max_pooling2d_6[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 12, 12, 128)  147584      ['conv2d_25[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 6, 6, 128)   0           ['conv2d_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 6, 6, 256)    295168      ['max_pooling2d_7[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 6, 6, 256)    590080      ['conv2d_27[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 12, 12, 128)  131200     ['conv2d_28[0][0]']
#  spose)
#
#  concatenate_4 (Concatenate)    (None, 12, 12, 256)  0           ['conv2d_transpose_4[0][0]',
#                                                                   'conv2d_26[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 12, 12, 128)  295040      ['concatenate_4[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 12, 12, 128)  147584      ['conv2d_29[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 24, 24, 64)  32832       ['conv2d_30[0][0]']
#  spose)
#
#  concatenate_5 (Concatenate)    (None, 24, 24, 128)  0           ['conv2d_transpose_5[0][0]',
#                                                                   'conv2d_24[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 24, 24, 64)   73792       ['concatenate_5[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 24, 24, 64)   36928       ['conv2d_31[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 48, 48, 32)  8224        ['conv2d_32[0][0]']
#  spose)
#
#  concatenate_6 (Concatenate)    (None, 48, 48, 64)   0           ['conv2d_transpose_6[0][0]',
#                                                                   'conv2d_22[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 48, 48, 32)   18464       ['concatenate_6[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 48, 48, 32)   9248        ['conv2d_33[0][0]']
#
#  conv2d_transpose_7 (Conv2DTran  (None, 96, 96, 16)  2064        ['conv2d_34[0][0]']
#  spose)
#
#  concatenate_7 (Concatenate)    (None, 96, 96, 32)   0           ['conv2d_transpose_7[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 96, 96, 16)   4624        ['concatenate_7[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 96, 96, 16)   2320        ['conv2d_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 96, 96, 1)    17          ['conv2d_36[0][0]']
#
# ==================================================================================================
# Total params: 1,941,105
# Trainable params: 1,941,105
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/150
# 80/80 [==============================] - 3s 20ms/step - loss: -0.7697 - iou: 0.6491 - val_loss: -0.8843 - val_iou: 0.7943
# Epoch 2/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9029 - iou: 0.8253 - val_loss: -0.9064 - val_iou: 0.8353
# Epoch 3/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9091 - iou: 0.8351 - val_loss: -0.9127 - val_iou: 0.8433
# Epoch 4/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9069 - iou: 0.8324 - val_loss: -0.9173 - val_iou: 0.8518
# Epoch 5/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9186 - iou: 0.8511 - val_loss: -0.9197 - val_iou: 0.8547
# Epoch 6/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9243 - iou: 0.8606 - val_loss: -0.9152 - val_iou: 0.8459
# Epoch 7/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9260 - iou: 0.8632 - val_loss: -0.9241 - val_iou: 0.8607
# Epoch 8/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9250 - iou: 0.8613 - val_loss: -0.9202 - val_iou: 0.8565
# Epoch 9/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9286 - iou: 0.8675 - val_loss: -0.9221 - val_iou: 0.8612
# Epoch 10/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9284 - iou: 0.8677 - val_loss: -0.9261 - val_iou: 0.8646
# Epoch 11/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9337 - iou: 0.8760 - val_loss: -0.9323 - val_iou: 0.8726
# Epoch 12/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9339 - iou: 0.8769 - val_loss: -0.9312 - val_iou: 0.8695
# Epoch 13/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9323 - iou: 0.8742 - val_loss: -0.9286 - val_iou: 0.8695
# Epoch 14/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9297 - iou: 0.8697 - val_loss: -0.9314 - val_iou: 0.8747
# Epoch 15/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9350 - iou: 0.8791 - val_loss: -0.9320 - val_iou: 0.8768
# Epoch 16/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9349 - iou: 0.8785 - val_loss: -0.9345 - val_iou: 0.8778
# Epoch 17/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9309 - iou: 0.8718 - val_loss: -0.9332 - val_iou: 0.8758
# Epoch 18/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9346 - iou: 0.8775 - val_loss: -0.9371 - val_iou: 0.8810
# Epoch 19/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9391 - iou: 0.8857 - val_loss: -0.9347 - val_iou: 0.8748
# Epoch 20/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9385 - iou: 0.8845 - val_loss: -0.9365 - val_iou: 0.8801
# Epoch 21/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9364 - iou: 0.8811 - val_loss: -0.9362 - val_iou: 0.8768
# Epoch 22/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9395 - iou: 0.8868 - val_loss: -0.9415 - val_iou: 0.8897
# Epoch 23/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9412 - iou: 0.8893 - val_loss: -0.9389 - val_iou: 0.8838
# Epoch 24/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9420 - iou: 0.8908 - val_loss: -0.9432 - val_iou: 0.8907
# Epoch 25/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9407 - iou: 0.8884 - val_loss: -0.9356 - val_iou: 0.8766
# Epoch 26/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9411 - iou: 0.8886 - val_loss: -0.9423 - val_iou: 0.8883
# Epoch 27/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9415 - iou: 0.8898 - val_loss: -0.9414 - val_iou: 0.8898
# Epoch 28/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9419 - iou: 0.8903 - val_loss: -0.9402 - val_iou: 0.8857
# Epoch 29/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9422 - iou: 0.8909 - val_loss: -0.9438 - val_iou: 0.8924
# Epoch 30/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9430 - iou: 0.8930 - val_loss: -0.9430 - val_iou: 0.8888
# Epoch 31/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9438 - iou: 0.8943 - val_loss: -0.9451 - val_iou: 0.8947
# Epoch 32/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9466 - iou: 0.8992 - val_loss: -0.9461 - val_iou: 0.8978
# Epoch 33/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9455 - iou: 0.8972 - val_loss: -0.9449 - val_iou: 0.8940
# Epoch 34/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9472 - iou: 0.9001 - val_loss: -0.9456 - val_iou: 0.8953
# Epoch 35/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9455 - iou: 0.8971 - val_loss: -0.9440 - val_iou: 0.8913
# Epoch 36/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9466 - iou: 0.8988 - val_loss: -0.9405 - val_iou: 0.8880
# Epoch 37/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9428 - iou: 0.8926 - val_loss: -0.9399 - val_iou: 0.8869
# Epoch 38/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9463 - iou: 0.8988 - val_loss: -0.9445 - val_iou: 0.8925
# Epoch 39/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9466 - iou: 0.8997 - val_loss: -0.9445 - val_iou: 0.8921
# Epoch 40/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9485 - iou: 0.9025 - val_loss: -0.9446 - val_iou: 0.8932
# Epoch 41/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9483 - iou: 0.9023 - val_loss: -0.9462 - val_iou: 0.8960
# Epoch 42/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9487 - iou: 0.9026 - val_loss: -0.9463 - val_iou: 0.8958
# Epoch 43/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9480 - iou: 0.9015 - val_loss: -0.9426 - val_iou: 0.8897
# Epoch 44/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9498 - iou: 0.9048 - val_loss: -0.9461 - val_iou: 0.8976
# Epoch 45/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9499 - iou: 0.9050 - val_loss: -0.9436 - val_iou: 0.8900
# Epoch 46/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9491 - iou: 0.9043 - val_loss: -0.9458 - val_iou: 0.8959
# Epoch 47/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9508 - iou: 0.9067 - val_loss: -0.9444 - val_iou: 0.8938
# Epoch 48/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9517 - iou: 0.9082 - val_loss: -0.9441 - val_iou: 0.8920
# Epoch 49/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9525 - iou: 0.9095 - val_loss: -0.9454 - val_iou: 0.8969
# Epoch 50/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9533 - iou: 0.9110 - val_loss: -0.9468 - val_iou: 0.8986
# Epoch 51/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9520 - iou: 0.9086 - val_loss: -0.9439 - val_iou: 0.8942
# Epoch 52/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9518 - iou: 0.9081 - val_loss: -0.9445 - val_iou: 0.8915
# Epoch 53/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9518 - iou: 0.9083 - val_loss: -0.9469 - val_iou: 0.8988
# Epoch 54/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9520 - iou: 0.9091 - val_loss: -0.9438 - val_iou: 0.8932
# Epoch 55/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9543 - iou: 0.9130 - val_loss: -0.9463 - val_iou: 0.8966
# Epoch 56/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9555 - iou: 0.9151 - val_loss: -0.9422 - val_iou: 0.8883
# Epoch 57/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9531 - iou: 0.9104 - val_loss: -0.9466 - val_iou: 0.8977
# Epoch 58/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9542 - iou: 0.9120 - val_loss: -0.9273 - val_iou: 0.8692
# Epoch 59/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9518 - iou: 0.9084 - val_loss: -0.9419 - val_iou: 0.8903
# Epoch 60/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9521 - iou: 0.9085 - val_loss: -0.9411 - val_iou: 0.8844
# Epoch 61/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9495 - iou: 0.9038 - val_loss: -0.9401 - val_iou: 0.8845
# Epoch 62/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9537 - iou: 0.9117 - val_loss: -0.9433 - val_iou: 0.8893
# Epoch 63/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9547 - iou: 0.9136 - val_loss: -0.9471 - val_iou: 0.8978
# Epoch 64/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9566 - iou: 0.9166 - val_loss: -0.9345 - val_iou: 0.8799
# Epoch 65/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9531 - iou: 0.9106 - val_loss: -0.9447 - val_iou: 0.8958
# Epoch 66/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9553 - iou: 0.9145 - val_loss: -0.9450 - val_iou: 0.8955
# Epoch 67/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9565 - iou: 0.9168 - val_loss: -0.9431 - val_iou: 0.8907
# Epoch 68/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9556 - iou: 0.9149 - val_loss: -0.9443 - val_iou: 0.8931
# Epoch 69/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9561 - iou: 0.9160 - val_loss: -0.9477 - val_iou: 0.8987
# Epoch 70/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9574 - iou: 0.9184 - val_loss: -0.9423 - val_iou: 0.8871
# Epoch 71/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9540 - iou: 0.9122 - val_loss: -0.9426 - val_iou: 0.8923
# Epoch 72/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9571 - iou: 0.9180 - val_loss: -0.9428 - val_iou: 0.8893
# Epoch 73/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9564 - iou: 0.9163 - val_loss: -0.9465 - val_iou: 0.8971
# Epoch 74/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9585 - iou: 0.9202 - val_loss: -0.9461 - val_iou: 0.8956
# Epoch 75/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9581 - iou: 0.9188 - val_loss: -0.9466 - val_iou: 0.8968
# Epoch 76/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9572 - iou: 0.9175 - val_loss: -0.9455 - val_iou: 0.8942
# Epoch 77/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9567 - iou: 0.9170 - val_loss: -0.9431 - val_iou: 0.8906
# Epoch 78/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9578 - iou: 0.9191 - val_loss: -0.9452 - val_iou: 0.8930
# Epoch 79/150
# 80/80 [==============================] - 1s 12ms/step - loss: -0.9592 - iou: 0.9217 - val_loss: -0.9470 - val_iou: 0.8987

# %%
plt.plot(results2.history['val_loss'])

# %%
plt.plot(results2.history['val_iou'])

# %%
plt.plot(results2.history['loss'])

# %%
plt.plot(results2.history['iou'])

# %%
cb = TimingCallback()

UNet_3 = UNet((96, 96, 3), activation_= TrainableLeakyReLU())
model3 = UNet_3.buildModel()
UNet_3.CompileandSummarize(model3)
results3 = model3.fit(x = X_train, y = Y_train, batch_size = 8, epochs=150, callbacks = [cb, tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)],  validation_data = (X_test, y_test))

training_inferences['TrainableLeakyReLU'] = sum(cb.logs)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 96, 96, 3)]  0           []
#
#  conv2d_38 (Conv2D)             (None, 96, 96, 16)   449         ['input_3[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 96, 96, 16)   2321        ['conv2d_38[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 48, 48, 16)  0           ['conv2d_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 48, 48, 32)   4641        ['max_pooling2d_8[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 48, 48, 32)   9249        ['conv2d_40[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 24, 24, 32)  0           ['conv2d_41[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 24, 24, 64)   18497       ['max_pooling2d_9[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 24, 24, 64)   36929       ['conv2d_42[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 12, 12, 64)  0           ['conv2d_43[0][0]']
#  )
#
#  conv2d_44 (Conv2D)             (None, 12, 12, 128)  73857       ['max_pooling2d_10[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 12, 12, 128)  147585      ['conv2d_44[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 6, 6, 128)   0           ['conv2d_45[0][0]']
#  )
#
#  conv2d_46 (Conv2D)             (None, 6, 6, 256)    295169      ['max_pooling2d_11[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 6, 6, 256)    590081      ['conv2d_46[0][0]']
#
#  conv2d_transpose_8 (Conv2DTran  (None, 12, 12, 128)  131200     ['conv2d_47[0][0]']
#  spose)
#
#  concatenate_8 (Concatenate)    (None, 12, 12, 256)  0           ['conv2d_transpose_8[0][0]',
#                                                                   'conv2d_45[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 12, 12, 128)  295041      ['concatenate_8[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 12, 12, 128)  147585      ['conv2d_48[0][0]']
#
#  conv2d_transpose_9 (Conv2DTran  (None, 24, 24, 64)  32832       ['conv2d_49[0][0]']
#  spose)
#
#  concatenate_9 (Concatenate)    (None, 24, 24, 128)  0           ['conv2d_transpose_9[0][0]',
#                                                                   'conv2d_43[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 24, 24, 64)   73793       ['concatenate_9[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 24, 24, 64)   36929       ['conv2d_50[0][0]']
#
#  conv2d_transpose_10 (Conv2DTra  (None, 48, 48, 32)  8224        ['conv2d_51[0][0]']
#  nspose)
#
#  concatenate_10 (Concatenate)   (None, 48, 48, 64)   0           ['conv2d_transpose_10[0][0]',
#                                                                   'conv2d_41[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 48, 48, 32)   18465       ['concatenate_10[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 48, 48, 32)   9249        ['conv2d_52[0][0]']
#
#  conv2d_transpose_11 (Conv2DTra  (None, 96, 96, 16)  2064        ['conv2d_53[0][0]']
#  nspose)
#
#  concatenate_11 (Concatenate)   (None, 96, 96, 32)   0           ['conv2d_transpose_11[0][0]',
#                                                                   'conv2d_39[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 96, 96, 16)   4625        ['concatenate_11[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 96, 96, 16)   2321        ['conv2d_54[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 96, 96, 1)    17          ['conv2d_55[0][0]']
#
# ==================================================================================================
# Total params: 1,941,106
# Trainable params: 1,941,106
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/150
# 80/80 [==============================] - 4s 18ms/step - loss: -0.7028 - iou: 0.5626 - val_loss: -0.7560 - val_iou: 0.6199
# Epoch 2/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.8606 - iou: 0.7607 - val_loss: -0.8655 - val_iou: 0.7811
# Epoch 3/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9020 - iou: 0.8225 - val_loss: -0.8906 - val_iou: 0.8179
# Epoch 4/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9106 - iou: 0.8376 - val_loss: -0.9136 - val_iou: 0.8430
# Epoch 5/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9036 - iou: 0.8262 - val_loss: -0.9020 - val_iou: 0.8309
# Epoch 6/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9071 - iou: 0.8323 - val_loss: -0.8909 - val_iou: 0.8163
# Epoch 7/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9183 - iou: 0.8501 - val_loss: -0.9206 - val_iou: 0.8562
# Epoch 8/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9269 - iou: 0.8643 - val_loss: -0.9203 - val_iou: 0.8584
# Epoch 9/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9252 - iou: 0.8622 - val_loss: -0.9203 - val_iou: 0.8534
# Epoch 10/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9299 - iou: 0.8696 - val_loss: -0.9278 - val_iou: 0.8659
# Epoch 11/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9283 - iou: 0.8670 - val_loss: -0.9207 - val_iou: 0.8566
# Epoch 12/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9272 - iou: 0.8650 - val_loss: -0.9294 - val_iou: 0.8678
# Epoch 13/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9315 - iou: 0.8723 - val_loss: -0.9297 - val_iou: 0.8704
# Epoch 14/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9301 - iou: 0.8707 - val_loss: -0.9258 - val_iou: 0.8648
# Epoch 15/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9311 - iou: 0.8720 - val_loss: -0.9299 - val_iou: 0.8701
# Epoch 16/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9345 - iou: 0.8761 - val_loss: -0.9339 - val_iou: 0.8756
# Epoch 17/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9340 - iou: 0.8766 - val_loss: -0.9342 - val_iou: 0.8759
# Epoch 18/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9347 - iou: 0.8780 - val_loss: -0.9335 - val_iou: 0.8752
# Epoch 19/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9090 - iou: 0.8436 - val_loss: -0.9071 - val_iou: 0.8371
# Epoch 20/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9197 - iou: 0.8523 - val_loss: -0.9191 - val_iou: 0.8508
# Epoch 21/150
# 80/80 [==============================] - 1s 17ms/step - loss: -0.9044 - iou: 0.8281 - val_loss: -0.8830 - val_iou: 0.8039
# Epoch 22/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9109 - iou: 0.8381 - val_loss: -0.9065 - val_iou: 0.8359
# Epoch 23/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9243 - iou: 0.8600 - val_loss: -0.9231 - val_iou: 0.8599
# Epoch 24/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9291 - iou: 0.8684 - val_loss: -0.9281 - val_iou: 0.8698
# Epoch 25/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9322 - iou: 0.8720 - val_loss: -0.9291 - val_iou: 0.8663
# Epoch 26/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9323 - iou: 0.8740 - val_loss: -0.9317 - val_iou: 0.8723
# Epoch 27/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9361 - iou: 0.8806 - val_loss: -0.9306 - val_iou: 0.8675

# %%
plt.plot(results3.history['val_loss'])

# %%
plt.plot(results3.history['val_iou'])

# %%
plt.plot(results3.history['loss'])

# %%
plt.plot(results3.history['iou'])

# %%
training_inferences
# Out:
# {'MexicanReLU': 125.468850857,
#  'Swish': 82.74901054199927,
#  'TrainableLeakyReLU': 32.940766922000535}

# %%
cb = TimingCallback()

UNet_4 = UNet((96, 96, 3), activation_= ISRU())
model4 = UNet_4.buildModel()
UNet_4.CompileandSummarize(model4)
results4 = model4.fit(x = X_train, y = Y_train, batch_size = 8, epochs=150, callbacks = [cb, tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)], validation_data = (X_test, y_test))

training_inferences['ISRU'] = sum(cb.logs)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 96, 96, 3)]  0           []
#
#  conv2d_57 (Conv2D)             (None, 96, 96, 16)   449         ['input_4[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 96, 96, 16)   2321        ['conv2d_57[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 48, 48, 16)  0           ['conv2d_58[0][0]']
#  )
#
#  conv2d_59 (Conv2D)             (None, 48, 48, 32)   4641        ['max_pooling2d_12[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 48, 48, 32)   9249        ['conv2d_59[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 24, 24, 32)  0           ['conv2d_60[0][0]']
#  )
#
#  conv2d_61 (Conv2D)             (None, 24, 24, 64)   18497       ['max_pooling2d_13[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 24, 24, 64)   36929       ['conv2d_61[0][0]']
#
#  max_pooling2d_14 (MaxPooling2D  (None, 12, 12, 64)  0           ['conv2d_62[0][0]']
#  )
#
#  conv2d_63 (Conv2D)             (None, 12, 12, 128)  73857       ['max_pooling2d_14[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 12, 12, 128)  147585      ['conv2d_63[0][0]']
#
#  max_pooling2d_15 (MaxPooling2D  (None, 6, 6, 128)   0           ['conv2d_64[0][0]']
#  )
#
#  conv2d_65 (Conv2D)             (None, 6, 6, 256)    295169      ['max_pooling2d_15[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 6, 6, 256)    590081      ['conv2d_65[0][0]']
#
#  conv2d_transpose_12 (Conv2DTra  (None, 12, 12, 128)  131200     ['conv2d_66[0][0]']
#  nspose)
#
#  concatenate_12 (Concatenate)   (None, 12, 12, 256)  0           ['conv2d_transpose_12[0][0]',
#                                                                   'conv2d_64[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 12, 12, 128)  295041      ['concatenate_12[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 12, 12, 128)  147585      ['conv2d_67[0][0]']
#
#  conv2d_transpose_13 (Conv2DTra  (None, 24, 24, 64)  32832       ['conv2d_68[0][0]']
#  nspose)
#
#  concatenate_13 (Concatenate)   (None, 24, 24, 128)  0           ['conv2d_transpose_13[0][0]',
#                                                                   'conv2d_62[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 24, 24, 64)   73793       ['concatenate_13[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 24, 24, 64)   36929       ['conv2d_69[0][0]']
#
#  conv2d_transpose_14 (Conv2DTra  (None, 48, 48, 32)  8224        ['conv2d_70[0][0]']
#  nspose)
#
#  concatenate_14 (Concatenate)   (None, 48, 48, 64)   0           ['conv2d_transpose_14[0][0]',
#                                                                   'conv2d_60[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 48, 48, 32)   18465       ['concatenate_14[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 48, 48, 32)   9249        ['conv2d_71[0][0]']
#
#  conv2d_transpose_15 (Conv2DTra  (None, 96, 96, 16)  2064        ['conv2d_72[0][0]']
#  nspose)
#
#  concatenate_15 (Concatenate)   (None, 96, 96, 32)   0           ['conv2d_transpose_15[0][0]',
#                                                                   'conv2d_58[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 96, 96, 16)   4625        ['concatenate_15[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 96, 96, 16)   2321        ['conv2d_73[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 96, 96, 1)    17          ['conv2d_74[0][0]']
#
# ==================================================================================================
# Total params: 1,941,106
# Trainable params: 1,941,106
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/150
# 80/80 [==============================] - 4s 20ms/step - loss: -0.6757 - iou: 0.5327 - val_loss: -0.8256 - val_iou: 0.7176
# Epoch 2/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.8616 - iou: 0.7589 - val_loss: -0.8661 - val_iou: 0.7714
# Epoch 3/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.8856 - iou: 0.7963 - val_loss: -0.8955 - val_iou: 0.8165
# Epoch 4/150
# 80/80 [==============================] - 1s 17ms/step - loss: -0.9069 - iou: 0.8307 - val_loss: -0.9137 - val_iou: 0.8406
# Epoch 5/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9152 - iou: 0.8444 - val_loss: -0.9182 - val_iou: 0.8497
# Epoch 6/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9178 - iou: 0.8490 - val_loss: -0.9144 - val_iou: 0.8437
# Epoch 7/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9169 - iou: 0.8473 - val_loss: -0.9226 - val_iou: 0.8559
# Epoch 8/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9244 - iou: 0.8594 - val_loss: -0.9262 - val_iou: 0.8607
# Epoch 9/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9260 - iou: 0.8627 - val_loss: -0.9271 - val_iou: 0.8608
# Epoch 10/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9238 - iou: 0.8592 - val_loss: -0.9298 - val_iou: 0.8664
# Epoch 11/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9276 - iou: 0.8649 - val_loss: -0.9291 - val_iou: 0.8672
# Epoch 12/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9286 - iou: 0.8672 - val_loss: -0.9178 - val_iou: 0.8511
# Epoch 13/150
# 80/80 [==============================] - 1s 17ms/step - loss: -0.9290 - iou: 0.8684 - val_loss: -0.9260 - val_iou: 0.8631
# Epoch 14/150
# 80/80 [==============================] - 1s 19ms/step - loss: -0.9313 - iou: 0.8723 - val_loss: -0.9281 - val_iou: 0.8658
# Epoch 15/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9315 - iou: 0.8724 - val_loss: -0.9310 - val_iou: 0.8677
# Epoch 16/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9306 - iou: 0.8714 - val_loss: -0.9251 - val_iou: 0.8637
# Epoch 17/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9333 - iou: 0.8757 - val_loss: -0.9340 - val_iou: 0.8729
# Epoch 18/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9344 - iou: 0.8774 - val_loss: -0.9333 - val_iou: 0.8709
# Epoch 19/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9358 - iou: 0.8793 - val_loss: -0.9182 - val_iou: 0.8474
# Epoch 20/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9306 - iou: 0.8710 - val_loss: -0.9332 - val_iou: 0.8758
# Epoch 21/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9356 - iou: 0.8797 - val_loss: -0.9365 - val_iou: 0.8777
# Epoch 22/150
# 80/80 [==============================] - 2s 19ms/step - loss: -0.9377 - iou: 0.8833 - val_loss: -0.9353 - val_iou: 0.8766
# Epoch 23/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9380 - iou: 0.8835 - val_loss: -0.9393 - val_iou: 0.8833
# Epoch 24/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9371 - iou: 0.8821 - val_loss: -0.9345 - val_iou: 0.8759
# Epoch 25/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9380 - iou: 0.8837 - val_loss: -0.9304 - val_iou: 0.8679
# Epoch 26/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9398 - iou: 0.8868 - val_loss: -0.9330 - val_iou: 0.8697
# Epoch 27/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9383 - iou: 0.8842 - val_loss: -0.9387 - val_iou: 0.8828
# Epoch 28/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9389 - iou: 0.8850 - val_loss: -0.9373 - val_iou: 0.8813
# Epoch 29/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9387 - iou: 0.8853 - val_loss: -0.9377 - val_iou: 0.8827
# Epoch 30/150
# 80/80 [==============================] - 1s 17ms/step - loss: -0.9415 - iou: 0.8903 - val_loss: -0.9367 - val_iou: 0.8828
# Epoch 31/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9428 - iou: 0.8920 - val_loss: -0.9392 - val_iou: 0.8811
# Epoch 32/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9432 - iou: 0.8932 - val_loss: -0.9391 - val_iou: 0.8834
# Epoch 33/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9432 - iou: 0.8923 - val_loss: -0.9419 - val_iou: 0.8861
# Epoch 34/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9425 - iou: 0.8924 - val_loss: -0.9391 - val_iou: 0.8809
# Epoch 35/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9431 - iou: 0.8923 - val_loss: -0.9435 - val_iou: 0.8893
# Epoch 36/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9396 - iou: 0.8864 - val_loss: -0.9413 - val_iou: 0.8875
# Epoch 37/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9420 - iou: 0.8903 - val_loss: -0.9414 - val_iou: 0.8842
# Epoch 38/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9342 - iou: 0.8778 - val_loss: -0.9397 - val_iou: 0.8821
# Epoch 39/150
# 80/80 [==============================] - 2s 23ms/step - loss: -0.9434 - iou: 0.8928 - val_loss: -0.9442 - val_iou: 0.8906
# Epoch 40/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9424 - iou: 0.8916 - val_loss: -0.9272 - val_iou: 0.8649
# Epoch 41/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9426 - iou: 0.8922 - val_loss: -0.9427 - val_iou: 0.8874
# Epoch 42/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9441 - iou: 0.8946 - val_loss: -0.9444 - val_iou: 0.8911
# Epoch 43/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9437 - iou: 0.8941 - val_loss: -0.9421 - val_iou: 0.8875
# Epoch 44/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9430 - iou: 0.8927 - val_loss: -0.9346 - val_iou: 0.8770
# Epoch 45/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9435 - iou: 0.8933 - val_loss: -0.9424 - val_iou: 0.8884
# Epoch 46/150
# 80/80 [==============================] - 1s 17ms/step - loss: -0.9457 - iou: 0.8970 - val_loss: -0.9331 - val_iou: 0.8679
# Epoch 47/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9416 - iou: 0.8913 - val_loss: -0.9424 - val_iou: 0.8873
# Epoch 48/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9458 - iou: 0.8973 - val_loss: -0.9249 - val_iou: 0.8624
# Epoch 49/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9427 - iou: 0.8921 - val_loss: -0.9448 - val_iou: 0.8932
# Epoch 50/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9459 - iou: 0.8982 - val_loss: -0.9361 - val_iou: 0.8781
# Epoch 51/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9442 - iou: 0.8945 - val_loss: -0.9464 - val_iou: 0.8943
# Epoch 52/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9439 - iou: 0.8946 - val_loss: -0.9436 - val_iou: 0.8875
# Epoch 53/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9474 - iou: 0.9000 - val_loss: -0.9429 - val_iou: 0.8917
# Epoch 54/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9452 - iou: 0.8968 - val_loss: -0.9451 - val_iou: 0.8926
# Epoch 55/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9455 - iou: 0.8970 - val_loss: -0.9462 - val_iou: 0.8942
# Epoch 56/150
# 80/80 [==============================] - 1s 17ms/step - loss: -0.9461 - iou: 0.8971 - val_loss: -0.9419 - val_iou: 0.8863
# Epoch 57/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9404 - iou: 0.8885 - val_loss: -0.9420 - val_iou: 0.8891
# Epoch 58/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9468 - iou: 0.8992 - val_loss: -0.9427 - val_iou: 0.8871
# Epoch 59/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9456 - iou: 0.8973 - val_loss: -0.9438 - val_iou: 0.8896
# Epoch 60/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9457 - iou: 0.8976 - val_loss: -0.9450 - val_iou: 0.8942
# Epoch 61/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9394 - iou: 0.8860 - val_loss: -0.9405 - val_iou: 0.8881

# %%
plt.plot(results4.history['val_loss'])

# %%
plt.plot(results3.history['val_iou'])

# %%
plt.plot(results3.history['loss'])

# %%
plt.plot(results3.history['iou'])

# %%
cb = TimingCallback()

UNet_5 = UNet((96, 96, 3), activation_= Mish())
model5 = UNet_5.buildModel()
UNet_5.CompileandSummarize(model5)
results5 = model5.fit(x = X_train, y = Y_train, batch_size = 8, epochs=150, callbacks = [cb, tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)], validation_data = (X_test, y_test))

training_inferences['Mish'] = sum(cb.logs)
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 96, 96, 3)]  0           []
#
#  conv2d_76 (Conv2D)             (None, 96, 96, 16)   448         ['input_5[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 96, 96, 16)   2320        ['conv2d_76[0][0]']
#
#  max_pooling2d_16 (MaxPooling2D  (None, 48, 48, 16)  0           ['conv2d_77[0][0]']
#  )
#
#  conv2d_78 (Conv2D)             (None, 48, 48, 32)   4640        ['max_pooling2d_16[0][0]']
#
#  conv2d_79 (Conv2D)             (None, 48, 48, 32)   9248        ['conv2d_78[0][0]']
#
#  max_pooling2d_17 (MaxPooling2D  (None, 24, 24, 32)  0           ['conv2d_79[0][0]']
#  )
#
#  conv2d_80 (Conv2D)             (None, 24, 24, 64)   18496       ['max_pooling2d_17[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 24, 24, 64)   36928       ['conv2d_80[0][0]']
#
#  max_pooling2d_18 (MaxPooling2D  (None, 12, 12, 64)  0           ['conv2d_81[0][0]']
#  )
#
#  conv2d_82 (Conv2D)             (None, 12, 12, 128)  73856       ['max_pooling2d_18[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 12, 12, 128)  147584      ['conv2d_82[0][0]']
#
#  max_pooling2d_19 (MaxPooling2D  (None, 6, 6, 128)   0           ['conv2d_83[0][0]']
#  )
#
#  conv2d_84 (Conv2D)             (None, 6, 6, 256)    295168      ['max_pooling2d_19[0][0]']
#
#  conv2d_85 (Conv2D)             (None, 6, 6, 256)    590080      ['conv2d_84[0][0]']
#
#  conv2d_transpose_16 (Conv2DTra  (None, 12, 12, 128)  131200     ['conv2d_85[0][0]']
#  nspose)
#
#  concatenate_16 (Concatenate)   (None, 12, 12, 256)  0           ['conv2d_transpose_16[0][0]',
#                                                                   'conv2d_83[0][0]']
#
#  conv2d_86 (Conv2D)             (None, 12, 12, 128)  295040      ['concatenate_16[0][0]']
#
#  conv2d_87 (Conv2D)             (None, 12, 12, 128)  147584      ['conv2d_86[0][0]']
#
#  conv2d_transpose_17 (Conv2DTra  (None, 24, 24, 64)  32832       ['conv2d_87[0][0]']
#  nspose)
#
#  concatenate_17 (Concatenate)   (None, 24, 24, 128)  0           ['conv2d_transpose_17[0][0]',
#                                                                   'conv2d_81[0][0]']
#
#  conv2d_88 (Conv2D)             (None, 24, 24, 64)   73792       ['concatenate_17[0][0]']
#
#  conv2d_89 (Conv2D)             (None, 24, 24, 64)   36928       ['conv2d_88[0][0]']
#
#  conv2d_transpose_18 (Conv2DTra  (None, 48, 48, 32)  8224        ['conv2d_89[0][0]']
#  nspose)
#
#  concatenate_18 (Concatenate)   (None, 48, 48, 64)   0           ['conv2d_transpose_18[0][0]',
#                                                                   'conv2d_79[0][0]']
#
#  conv2d_90 (Conv2D)             (None, 48, 48, 32)   18464       ['concatenate_18[0][0]']
#
#  conv2d_91 (Conv2D)             (None, 48, 48, 32)   9248        ['conv2d_90[0][0]']
#
#  conv2d_transpose_19 (Conv2DTra  (None, 96, 96, 16)  2064        ['conv2d_91[0][0]']
#  nspose)
#
#  concatenate_19 (Concatenate)   (None, 96, 96, 32)   0           ['conv2d_transpose_19[0][0]',
#                                                                   'conv2d_77[0][0]']
#
#  conv2d_92 (Conv2D)             (None, 96, 96, 16)   4624        ['concatenate_19[0][0]']
#
#  conv2d_93 (Conv2D)             (None, 96, 96, 16)   2320        ['conv2d_92[0][0]']
#
#  conv2d_94 (Conv2D)             (None, 96, 96, 1)    17          ['conv2d_93[0][0]']
#
# ==================================================================================================
# Total params: 1,941,105
# Trainable params: 1,941,105
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/150
# 80/80 [==============================] - 3s 18ms/step - loss: -0.7057 - iou: 0.5638 - val_loss: -0.8623 - val_iou: 0.7716
# Epoch 2/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.8887 - iou: 0.8012 - val_loss: -0.8941 - val_iou: 0.8160
# Epoch 3/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9063 - iou: 0.8305 - val_loss: -0.9089 - val_iou: 0.8380
# Epoch 4/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9179 - iou: 0.8494 - val_loss: -0.9060 - val_iou: 0.8340
# Epoch 5/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9186 - iou: 0.8513 - val_loss: -0.9202 - val_iou: 0.8563
# Epoch 6/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9217 - iou: 0.8563 - val_loss: -0.9113 - val_iou: 0.8413
# Epoch 7/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9232 - iou: 0.8587 - val_loss: -0.9292 - val_iou: 0.8675
# Epoch 8/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9273 - iou: 0.8653 - val_loss: -0.9299 - val_iou: 0.8697
# Epoch 9/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9301 - iou: 0.8703 - val_loss: -0.9273 - val_iou: 0.8690
# Epoch 10/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9310 - iou: 0.8718 - val_loss: -0.9251 - val_iou: 0.8645
# Epoch 11/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9336 - iou: 0.8764 - val_loss: -0.9234 - val_iou: 0.8580
# Epoch 12/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9347 - iou: 0.8780 - val_loss: -0.9355 - val_iou: 0.8779
# Epoch 13/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9360 - iou: 0.8807 - val_loss: -0.9363 - val_iou: 0.8806
# Epoch 14/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9356 - iou: 0.8797 - val_loss: -0.9285 - val_iou: 0.8656
# Epoch 15/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9316 - iou: 0.8730 - val_loss: -0.9377 - val_iou: 0.8821
# Epoch 16/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9376 - iou: 0.8836 - val_loss: -0.9406 - val_iou: 0.8855
# Epoch 17/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9387 - iou: 0.8848 - val_loss: -0.9382 - val_iou: 0.8828
# Epoch 18/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9400 - iou: 0.8873 - val_loss: -0.9409 - val_iou: 0.8881
# Epoch 19/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9378 - iou: 0.8838 - val_loss: -0.9369 - val_iou: 0.8820
# Epoch 20/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9398 - iou: 0.8873 - val_loss: -0.9394 - val_iou: 0.8841
# Epoch 21/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9408 - iou: 0.8889 - val_loss: -0.9413 - val_iou: 0.8874
# Epoch 22/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9433 - iou: 0.8927 - val_loss: -0.9366 - val_iou: 0.8782
# Epoch 23/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9415 - iou: 0.8900 - val_loss: -0.9399 - val_iou: 0.8849
# Epoch 24/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9433 - iou: 0.8932 - val_loss: -0.9404 - val_iou: 0.8877
# Epoch 25/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9443 - iou: 0.8948 - val_loss: -0.9435 - val_iou: 0.8902
# Epoch 26/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9441 - iou: 0.8939 - val_loss: -0.9396 - val_iou: 0.8848
# Epoch 27/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9451 - iou: 0.8961 - val_loss: -0.9443 - val_iou: 0.8931
# Epoch 28/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9452 - iou: 0.8961 - val_loss: -0.9400 - val_iou: 0.8873
# Epoch 29/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9461 - iou: 0.8984 - val_loss: -0.9419 - val_iou: 0.8911
# Epoch 30/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9450 - iou: 0.8960 - val_loss: -0.9434 - val_iou: 0.8908
# Epoch 31/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9483 - iou: 0.9018 - val_loss: -0.9437 - val_iou: 0.8921
# Epoch 32/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9452 - iou: 0.8967 - val_loss: -0.9433 - val_iou: 0.8909
# Epoch 33/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9486 - iou: 0.9027 - val_loss: -0.9458 - val_iou: 0.8964
# Epoch 34/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9491 - iou: 0.9029 - val_loss: -0.9461 - val_iou: 0.8955
# Epoch 35/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9493 - iou: 0.9040 - val_loss: -0.9437 - val_iou: 0.8915
# Epoch 36/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9504 - iou: 0.9064 - val_loss: -0.9427 - val_iou: 0.8901
# Epoch 37/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9464 - iou: 0.8988 - val_loss: -0.9459 - val_iou: 0.8948
# Epoch 38/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9495 - iou: 0.9044 - val_loss: -0.9445 - val_iou: 0.8924
# Epoch 39/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9501 - iou: 0.9053 - val_loss: -0.9436 - val_iou: 0.8918
# Epoch 40/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9530 - iou: 0.9106 - val_loss: -0.9400 - val_iou: 0.8854
# Epoch 41/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9518 - iou: 0.9083 - val_loss: -0.9455 - val_iou: 0.8927
# Epoch 42/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9537 - iou: 0.9112 - val_loss: -0.9460 - val_iou: 0.8948
# Epoch 43/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9541 - iou: 0.9126 - val_loss: -0.9471 - val_iou: 0.8969
# Epoch 44/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9550 - iou: 0.9141 - val_loss: -0.9467 - val_iou: 0.8955
# Epoch 45/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9552 - iou: 0.9143 - val_loss: -0.9428 - val_iou: 0.8893
# Epoch 46/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9470 - iou: 0.8999 - val_loss: -0.9436 - val_iou: 0.8912
# Epoch 47/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9543 - iou: 0.9125 - val_loss: -0.9460 - val_iou: 0.8930
# Epoch 48/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9546 - iou: 0.9136 - val_loss: -0.9471 - val_iou: 0.8976
# Epoch 49/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9561 - iou: 0.9161 - val_loss: -0.9466 - val_iou: 0.8962
# Epoch 50/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9575 - iou: 0.9184 - val_loss: -0.9483 - val_iou: 0.8993
# Epoch 51/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9583 - iou: 0.9200 - val_loss: -0.9433 - val_iou: 0.8883
# Epoch 52/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9552 - iou: 0.9144 - val_loss: -0.9452 - val_iou: 0.8942
# Epoch 53/150
# 80/80 [==============================] - 1s 17ms/step - loss: -0.9583 - iou: 0.9201 - val_loss: -0.9466 - val_iou: 0.8966
# Epoch 54/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9586 - iou: 0.9208 - val_loss: -0.9463 - val_iou: 0.8944
# Epoch 55/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9579 - iou: 0.9190 - val_loss: -0.9469 - val_iou: 0.8975
# Epoch 56/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9590 - iou: 0.9213 - val_loss: -0.9478 - val_iou: 0.8970
# Epoch 57/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9600 - iou: 0.9231 - val_loss: -0.9459 - val_iou: 0.8953
# Epoch 58/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9600 - iou: 0.9232 - val_loss: -0.9468 - val_iou: 0.8966
# Epoch 59/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9613 - iou: 0.9252 - val_loss: -0.9473 - val_iou: 0.8966
# Epoch 60/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9608 - iou: 0.9249 - val_loss: -0.9432 - val_iou: 0.8907

# %%
plt.plot(results5.history['val_loss'])

# %%
plt.plot(results5.history['val_iou'])

# %%
plt.plot(results5.history['loss'])

# %%
plt.plot(results5.history['iou'])

# %%
cb = TimingCallback()

UNet_6 = UNet((96, 96, 3), activation_= gated_swish())
model6 = UNet_6.buildModel()
UNet_6.CompileandSummarize(model6)
results6 = model6.fit(x = X_train, y = Y_train, batch_size = 8, epochs=150, callbacks = [cb, tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)], validation_data = (X_test, y_test))

training_inferences['gated_swish'] = sum(cb.logs)
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 96, 96, 3)]  0           []
#
#  conv2d_95 (Conv2D)             (None, 96, 96, 16)   448         ['input_6[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 96, 96, 16)   2320        ['conv2d_95[0][0]']
#
#  max_pooling2d_20 (MaxPooling2D  (None, 48, 48, 16)  0           ['conv2d_96[0][0]']
#  )
#
#  conv2d_97 (Conv2D)             (None, 48, 48, 32)   4640        ['max_pooling2d_20[0][0]']
#
#  conv2d_98 (Conv2D)             (None, 48, 48, 32)   9248        ['conv2d_97[0][0]']
#
#  max_pooling2d_21 (MaxPooling2D  (None, 24, 24, 32)  0           ['conv2d_98[0][0]']
#  )
#
#  conv2d_99 (Conv2D)             (None, 24, 24, 64)   18496       ['max_pooling2d_21[0][0]']
#
#  conv2d_100 (Conv2D)            (None, 24, 24, 64)   36928       ['conv2d_99[0][0]']
#
#  max_pooling2d_22 (MaxPooling2D  (None, 12, 12, 64)  0           ['conv2d_100[0][0]']
#  )
#
#  conv2d_101 (Conv2D)            (None, 12, 12, 128)  73856       ['max_pooling2d_22[0][0]']
#
#  conv2d_102 (Conv2D)            (None, 12, 12, 128)  147584      ['conv2d_101[0][0]']
#
#  max_pooling2d_23 (MaxPooling2D  (None, 6, 6, 128)   0           ['conv2d_102[0][0]']
#  )
#
#  conv2d_103 (Conv2D)            (None, 6, 6, 256)    295168      ['max_pooling2d_23[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 6, 6, 256)    590080      ['conv2d_103[0][0]']
#
#  conv2d_transpose_20 (Conv2DTra  (None, 12, 12, 128)  131200     ['conv2d_104[0][0]']
#  nspose)
#
#  concatenate_20 (Concatenate)   (None, 12, 12, 256)  0           ['conv2d_transpose_20[0][0]',
#                                                                   'conv2d_102[0][0]']
#
#  conv2d_105 (Conv2D)            (None, 12, 12, 128)  295040      ['concatenate_20[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 12, 12, 128)  147584      ['conv2d_105[0][0]']
#
#  conv2d_transpose_21 (Conv2DTra  (None, 24, 24, 64)  32832       ['conv2d_106[0][0]']
#  nspose)
#
#  concatenate_21 (Concatenate)   (None, 24, 24, 128)  0           ['conv2d_transpose_21[0][0]',
#                                                                   'conv2d_100[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 24, 24, 64)   73792       ['concatenate_21[0][0]']
#
#  conv2d_108 (Conv2D)            (None, 24, 24, 64)   36928       ['conv2d_107[0][0]']
#
#  conv2d_transpose_22 (Conv2DTra  (None, 48, 48, 32)  8224        ['conv2d_108[0][0]']
#  nspose)
#
#  concatenate_22 (Concatenate)   (None, 48, 48, 64)   0           ['conv2d_transpose_22[0][0]',
#                                                                   'conv2d_98[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 48, 48, 32)   18464       ['concatenate_22[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 48, 48, 32)   9248        ['conv2d_109[0][0]']
#
#  conv2d_transpose_23 (Conv2DTra  (None, 96, 96, 16)  2064        ['conv2d_110[0][0]']
#  nspose)
#
#  concatenate_23 (Concatenate)   (None, 96, 96, 32)   0           ['conv2d_transpose_23[0][0]',
#                                                                   'conv2d_96[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 96, 96, 16)   4624        ['concatenate_23[0][0]']
#
#  conv2d_112 (Conv2D)            (None, 96, 96, 16)   2320        ['conv2d_111[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 96, 96, 1)    17          ['conv2d_112[0][0]']
#
# ==================================================================================================
# Total params: 1,941,105
# Trainable params: 1,941,105
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/150
# 80/80 [==============================] - 4s 19ms/step - loss: -0.7251 - iou: 0.5902 - val_loss: -0.7581 - val_iou: 0.6297
# Epoch 2/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.8498 - iou: 0.7463 - val_loss: -0.8979 - val_iou: 0.8163
# Epoch 3/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9049 - iou: 0.8271 - val_loss: -0.9166 - val_iou: 0.8490
# Epoch 4/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9124 - iou: 0.8407 - val_loss: -0.9163 - val_iou: 0.8486
# Epoch 5/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9110 - iou: 0.8383 - val_loss: -0.9091 - val_iou: 0.8408
# Epoch 6/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9165 - iou: 0.8474 - val_loss: -0.9253 - val_iou: 0.8603
# Epoch 7/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9218 - iou: 0.8561 - val_loss: -0.9219 - val_iou: 0.8603
# Epoch 8/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9195 - iou: 0.8527 - val_loss: -0.9271 - val_iou: 0.8639
# Epoch 9/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9114 - iou: 0.8391 - val_loss: -0.9124 - val_iou: 0.8419
# Epoch 10/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9166 - iou: 0.8472 - val_loss: -0.9188 - val_iou: 0.8524
# Epoch 11/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9209 - iou: 0.8555 - val_loss: -0.9199 - val_iou: 0.8515
# Epoch 12/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9250 - iou: 0.8621 - val_loss: -0.9223 - val_iou: 0.8574
# Epoch 13/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9256 - iou: 0.8623 - val_loss: -0.9271 - val_iou: 0.8639
# Epoch 14/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9258 - iou: 0.8632 - val_loss: -0.9193 - val_iou: 0.8568
# Epoch 15/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9279 - iou: 0.8671 - val_loss: -0.9287 - val_iou: 0.8688
# Epoch 16/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9273 - iou: 0.8653 - val_loss: -0.9196 - val_iou: 0.8575
# Epoch 17/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9315 - iou: 0.8729 - val_loss: -0.9326 - val_iou: 0.8718
# Epoch 18/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9279 - iou: 0.8661 - val_loss: -0.9202 - val_iou: 0.8589
# Epoch 19/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9301 - iou: 0.8703 - val_loss: -0.9346 - val_iou: 0.8777
# Epoch 20/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9343 - iou: 0.8763 - val_loss: -0.9383 - val_iou: 0.8838
# Epoch 21/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9338 - iou: 0.8760 - val_loss: -0.9306 - val_iou: 0.8726
# Epoch 22/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9311 - iou: 0.8715 - val_loss: -0.9366 - val_iou: 0.8786
# Epoch 23/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9304 - iou: 0.8707 - val_loss: -0.9343 - val_iou: 0.8764
# Epoch 24/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9356 - iou: 0.8796 - val_loss: -0.9339 - val_iou: 0.8755
# Epoch 25/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9352 - iou: 0.8797 - val_loss: -0.9342 - val_iou: 0.8732
# Epoch 26/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9369 - iou: 0.8818 - val_loss: -0.9393 - val_iou: 0.8836
# Epoch 27/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9377 - iou: 0.8828 - val_loss: -0.9409 - val_iou: 0.8888
# Epoch 28/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9358 - iou: 0.8802 - val_loss: -0.9378 - val_iou: 0.8809
# Epoch 29/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9380 - iou: 0.8832 - val_loss: -0.9385 - val_iou: 0.8832
# Epoch 30/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9396 - iou: 0.8865 - val_loss: -0.9375 - val_iou: 0.8800
# Epoch 31/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9396 - iou: 0.8866 - val_loss: -0.9370 - val_iou: 0.8814
# Epoch 32/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9377 - iou: 0.8835 - val_loss: -0.9374 - val_iou: 0.8775
# Epoch 33/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9406 - iou: 0.8884 - val_loss: -0.9408 - val_iou: 0.8870
# Epoch 34/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9382 - iou: 0.8842 - val_loss: -0.9407 - val_iou: 0.8858
# Epoch 35/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9396 - iou: 0.8869 - val_loss: -0.9404 - val_iou: 0.8844
# Epoch 36/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9415 - iou: 0.8897 - val_loss: -0.9433 - val_iou: 0.8909
# Epoch 37/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9410 - iou: 0.8892 - val_loss: -0.9411 - val_iou: 0.8895
# Epoch 38/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9427 - iou: 0.8917 - val_loss: -0.9416 - val_iou: 0.8859
# Epoch 39/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9415 - iou: 0.8903 - val_loss: -0.9360 - val_iou: 0.8769
# Epoch 40/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9420 - iou: 0.8909 - val_loss: -0.9424 - val_iou: 0.8875
# Epoch 41/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9444 - iou: 0.8951 - val_loss: -0.9431 - val_iou: 0.8916
# Epoch 42/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9428 - iou: 0.8925 - val_loss: -0.9391 - val_iou: 0.8828
# Epoch 43/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9411 - iou: 0.8896 - val_loss: -0.9436 - val_iou: 0.8914
# Epoch 44/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9423 - iou: 0.8918 - val_loss: -0.9414 - val_iou: 0.8860
# Epoch 45/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9436 - iou: 0.8940 - val_loss: -0.9440 - val_iou: 0.8902
# Epoch 46/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9439 - iou: 0.8938 - val_loss: -0.9445 - val_iou: 0.8934
# Epoch 47/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9438 - iou: 0.8940 - val_loss: -0.9434 - val_iou: 0.8893
# Epoch 48/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9445 - iou: 0.8952 - val_loss: -0.9434 - val_iou: 0.8897
# Epoch 49/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9444 - iou: 0.8951 - val_loss: -0.9420 - val_iou: 0.8887
# Epoch 50/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9426 - iou: 0.8923 - val_loss: -0.9427 - val_iou: 0.8892
# Epoch 51/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9436 - iou: 0.8938 - val_loss: -0.9414 - val_iou: 0.8859
# Epoch 52/150
# 80/80 [==============================] - 2s 19ms/step - loss: -0.9437 - iou: 0.8942 - val_loss: -0.9457 - val_iou: 0.8943
# Epoch 53/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9445 - iou: 0.8954 - val_loss: -0.9454 - val_iou: 0.8954
# Epoch 54/150
# 80/80 [==============================] - 1s 17ms/step - loss: -0.9435 - iou: 0.8933 - val_loss: -0.9426 - val_iou: 0.8888
# Epoch 55/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9461 - iou: 0.8983 - val_loss: -0.9452 - val_iou: 0.8964
# Epoch 56/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9446 - iou: 0.8958 - val_loss: -0.9393 - val_iou: 0.8819
# Epoch 57/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9434 - iou: 0.8939 - val_loss: -0.9471 - val_iou: 0.9001
# Epoch 58/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9476 - iou: 0.9008 - val_loss: -0.9431 - val_iou: 0.8887
# Epoch 59/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9452 - iou: 0.8965 - val_loss: -0.9323 - val_iou: 0.8763
# Epoch 60/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9436 - iou: 0.8935 - val_loss: -0.9406 - val_iou: 0.8853
# Epoch 61/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9446 - iou: 0.8956 - val_loss: -0.9442 - val_iou: 0.8906
# Epoch 62/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9445 - iou: 0.8954 - val_loss: -0.9468 - val_iou: 0.8969
# Epoch 63/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9479 - iou: 0.8998 - val_loss: -0.9426 - val_iou: 0.8902
# Epoch 64/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9473 - iou: 0.9003 - val_loss: -0.9441 - val_iou: 0.8936
# Epoch 65/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9485 - iou: 0.9026 - val_loss: -0.9396 - val_iou: 0.8859
# Epoch 66/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9469 - iou: 0.8991 - val_loss: -0.9453 - val_iou: 0.8960
# Epoch 67/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9473 - iou: 0.8997 - val_loss: -0.9461 - val_iou: 0.8969

# %%
plt.plot(results6.history['val_loss'])

# %%
plt.plot(results6.history['val_iou'])

# %%
plt.plot(results6.history['iou'])

# %%
plt.plot(results6.history['loss'])

# %%
cb = TimingCallback()

UNet__ = UNet((96, 96, 3), activation_= "relu")
model_ = UNet__.buildModel()
UNet__.CompileandSummarize(model_)
results_ = model5.fit(x = X_train, y = Y_train, batch_size = 8, epochs=150, callbacks = [cb, tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)], validation_data = (X_test, y_test))

training_inferences['relu'] = sum(cb.logs)
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 96, 96, 3)]  0           []
#
#  conv2d_114 (Conv2D)            (None, 96, 96, 16)   448         ['input_7[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 96, 96, 16)   2320        ['conv2d_114[0][0]']
#
#  max_pooling2d_24 (MaxPooling2D  (None, 48, 48, 16)  0           ['conv2d_115[0][0]']
#  )
#
#  conv2d_116 (Conv2D)            (None, 48, 48, 32)   4640        ['max_pooling2d_24[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 48, 48, 32)   9248        ['conv2d_116[0][0]']
#
#  max_pooling2d_25 (MaxPooling2D  (None, 24, 24, 32)  0           ['conv2d_117[0][0]']
#  )
#
#  conv2d_118 (Conv2D)            (None, 24, 24, 64)   18496       ['max_pooling2d_25[0][0]']
#
#  conv2d_119 (Conv2D)            (None, 24, 24, 64)   36928       ['conv2d_118[0][0]']
#
#  max_pooling2d_26 (MaxPooling2D  (None, 12, 12, 64)  0           ['conv2d_119[0][0]']
#  )
#
#  conv2d_120 (Conv2D)            (None, 12, 12, 128)  73856       ['max_pooling2d_26[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 12, 12, 128)  147584      ['conv2d_120[0][0]']
#
#  max_pooling2d_27 (MaxPooling2D  (None, 6, 6, 128)   0           ['conv2d_121[0][0]']
#  )
#
#  conv2d_122 (Conv2D)            (None, 6, 6, 256)    295168      ['max_pooling2d_27[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 6, 6, 256)    590080      ['conv2d_122[0][0]']
#
#  conv2d_transpose_24 (Conv2DTra  (None, 12, 12, 128)  131200     ['conv2d_123[0][0]']
#  nspose)
#
#  concatenate_24 (Concatenate)   (None, 12, 12, 256)  0           ['conv2d_transpose_24[0][0]',
#                                                                   'conv2d_121[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 12, 12, 128)  295040      ['concatenate_24[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 12, 12, 128)  147584      ['conv2d_124[0][0]']
#
#  conv2d_transpose_25 (Conv2DTra  (None, 24, 24, 64)  32832       ['conv2d_125[0][0]']
#  nspose)
#
#  concatenate_25 (Concatenate)   (None, 24, 24, 128)  0           ['conv2d_transpose_25[0][0]',
#                                                                   'conv2d_119[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 24, 24, 64)   73792       ['concatenate_25[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 24, 24, 64)   36928       ['conv2d_126[0][0]']
#
#  conv2d_transpose_26 (Conv2DTra  (None, 48, 48, 32)  8224        ['conv2d_127[0][0]']
#  nspose)
#
#  concatenate_26 (Concatenate)   (None, 48, 48, 64)   0           ['conv2d_transpose_26[0][0]',
#                                                                   'conv2d_117[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 48, 48, 32)   18464       ['concatenate_26[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 48, 48, 32)   9248        ['conv2d_128[0][0]']
#
#  conv2d_transpose_27 (Conv2DTra  (None, 96, 96, 16)  2064        ['conv2d_129[0][0]']
#  nspose)
#
#  concatenate_27 (Concatenate)   (None, 96, 96, 32)   0           ['conv2d_transpose_27[0][0]',
#                                                                   'conv2d_115[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 96, 96, 16)   4624        ['concatenate_27[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 96, 96, 16)   2320        ['conv2d_130[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 96, 96, 1)    17          ['conv2d_131[0][0]']
#
# ==================================================================================================
# Total params: 1,941,105
# Trainable params: 1,941,105
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9603 - iou: 0.9235 - val_loss: -0.9452 - val_iou: 0.8942
# Epoch 2/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9607 - iou: 0.9243 - val_loss: -0.9472 - val_iou: 0.8977
# Epoch 3/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9596 - iou: 0.9224 - val_loss: -0.9465 - val_iou: 0.8955
# Epoch 4/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9607 - iou: 0.9243 - val_loss: -0.9455 - val_iou: 0.8929
# Epoch 5/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9603 - iou: 0.9237 - val_loss: -0.9463 - val_iou: 0.8950
# Epoch 6/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9615 - iou: 0.9260 - val_loss: -0.9471 - val_iou: 0.8965
# Epoch 7/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9609 - iou: 0.9247 - val_loss: -0.9461 - val_iou: 0.8944
# Epoch 8/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9626 - iou: 0.9277 - val_loss: -0.9459 - val_iou: 0.8954
# Epoch 9/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9619 - iou: 0.9268 - val_loss: -0.9445 - val_iou: 0.8913
# Epoch 10/150
# 80/80 [==============================] - 1s 17ms/step - loss: -0.9616 - iou: 0.9262 - val_loss: -0.9448 - val_iou: 0.8926
# Epoch 11/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9614 - iou: 0.9255 - val_loss: -0.9477 - val_iou: 0.8981
# Epoch 12/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9628 - iou: 0.9280 - val_loss: -0.9453 - val_iou: 0.8915
# Epoch 13/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9599 - iou: 0.9228 - val_loss: -0.9455 - val_iou: 0.8936
# Epoch 14/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9602 - iou: 0.9237 - val_loss: -0.9455 - val_iou: 0.8948
# Epoch 15/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9616 - iou: 0.9260 - val_loss: -0.9468 - val_iou: 0.8967
# Epoch 16/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9574 - iou: 0.9183 - val_loss: -0.9444 - val_iou: 0.8936
# Epoch 17/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9562 - iou: 0.9159 - val_loss: -0.9455 - val_iou: 0.8939
# Epoch 18/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9601 - iou: 0.9232 - val_loss: -0.9469 - val_iou: 0.8953
# Epoch 19/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9626 - iou: 0.9279 - val_loss: -0.9469 - val_iou: 0.8973
# Epoch 20/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9629 - iou: 0.9284 - val_loss: -0.9448 - val_iou: 0.8914
# Epoch 21/150
# 80/80 [==============================] - 1s 13ms/step - loss: -0.9621 - iou: 0.9270 - val_loss: -0.9468 - val_iou: 0.8963

# %%
plt.plot(results_.history['val_loss'])

# %%
plt.plot(results_.history['val_iou'])

# %%
plt.plot(results_.history['loss'])

# %%
plt.plot(results_.history['iou'])

# %%
cb = TimingCallback()

UNet_ls = UNet((96, 96, 3), activation_= LearnableSwish())
modells = UNet_ls.buildModel()
UNet_ls.CompileandSummarize(modells)
resultsls = modells.fit(x = X_train, y = Y_train, batch_size = 8, epochs=150, callbacks = [cb, tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)], validation_data = (X_test, y_test))

training_inferences['LearnableSwish'] = sum(cb.logs)
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 96, 96, 3)]  0           []
#
#  conv2d_133 (Conv2D)            (None, 96, 96, 16)   449         ['input_8[0][0]']
#
#  conv2d_134 (Conv2D)            (None, 96, 96, 16)   2321        ['conv2d_133[0][0]']
#
#  max_pooling2d_28 (MaxPooling2D  (None, 48, 48, 16)  0           ['conv2d_134[0][0]']
#  )
#
#  conv2d_135 (Conv2D)            (None, 48, 48, 32)   4641        ['max_pooling2d_28[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 48, 48, 32)   9249        ['conv2d_135[0][0]']
#
#  max_pooling2d_29 (MaxPooling2D  (None, 24, 24, 32)  0           ['conv2d_136[0][0]']
#  )
#
#  conv2d_137 (Conv2D)            (None, 24, 24, 64)   18497       ['max_pooling2d_29[0][0]']
#
#  conv2d_138 (Conv2D)            (None, 24, 24, 64)   36929       ['conv2d_137[0][0]']
#
#  max_pooling2d_30 (MaxPooling2D  (None, 12, 12, 64)  0           ['conv2d_138[0][0]']
#  )
#
#  conv2d_139 (Conv2D)            (None, 12, 12, 128)  73857       ['max_pooling2d_30[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 12, 12, 128)  147585      ['conv2d_139[0][0]']
#
#  max_pooling2d_31 (MaxPooling2D  (None, 6, 6, 128)   0           ['conv2d_140[0][0]']
#  )
#
#  conv2d_141 (Conv2D)            (None, 6, 6, 256)    295169      ['max_pooling2d_31[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 6, 6, 256)    590081      ['conv2d_141[0][0]']
#
#  conv2d_transpose_28 (Conv2DTra  (None, 12, 12, 128)  131200     ['conv2d_142[0][0]']
#  nspose)
#
#  concatenate_28 (Concatenate)   (None, 12, 12, 256)  0           ['conv2d_transpose_28[0][0]',
#                                                                   'conv2d_140[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 12, 12, 128)  295041      ['concatenate_28[0][0]']
#
#  conv2d_144 (Conv2D)            (None, 12, 12, 128)  147585      ['conv2d_143[0][0]']
#
#  conv2d_transpose_29 (Conv2DTra  (None, 24, 24, 64)  32832       ['conv2d_144[0][0]']
#  nspose)
#
#  concatenate_29 (Concatenate)   (None, 24, 24, 128)  0           ['conv2d_transpose_29[0][0]',
#                                                                   'conv2d_138[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 24, 24, 64)   73793       ['concatenate_29[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 24, 24, 64)   36929       ['conv2d_145[0][0]']
#
#  conv2d_transpose_30 (Conv2DTra  (None, 48, 48, 32)  8224        ['conv2d_146[0][0]']
#  nspose)
#
#  concatenate_30 (Concatenate)   (None, 48, 48, 64)   0           ['conv2d_transpose_30[0][0]',
#                                                                   'conv2d_136[0][0]']
#
#  conv2d_147 (Conv2D)            (None, 48, 48, 32)   18465       ['concatenate_30[0][0]']
#
#  conv2d_148 (Conv2D)            (None, 48, 48, 32)   9249        ['conv2d_147[0][0]']
#
#  conv2d_transpose_31 (Conv2DTra  (None, 96, 96, 16)  2064        ['conv2d_148[0][0]']
#  nspose)
#
#  concatenate_31 (Concatenate)   (None, 96, 96, 32)   0           ['conv2d_transpose_31[0][0]',
#                                                                   'conv2d_134[0][0]']
#
#  conv2d_149 (Conv2D)            (None, 96, 96, 16)   4625        ['concatenate_31[0][0]']
#
#  conv2d_150 (Conv2D)            (None, 96, 96, 16)   2321        ['conv2d_149[0][0]']
#
#  conv2d_151 (Conv2D)            (None, 96, 96, 1)    17          ['conv2d_150[0][0]']
#
# ==================================================================================================
# Total params: 1,941,106
# Trainable params: 1,941,106
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/150
# 80/80 [==============================] - 4s 20ms/step - loss: -0.6775 - iou: 0.5374 - val_loss: -0.8255 - val_iou: 0.7148
# Epoch 2/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.8883 - iou: 0.8019 - val_loss: -0.8991 - val_iou: 0.8296
# Epoch 3/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9088 - iou: 0.8349 - val_loss: -0.9145 - val_iou: 0.8483
# Epoch 4/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9184 - iou: 0.8502 - val_loss: -0.9082 - val_iou: 0.8351
# Epoch 5/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9192 - iou: 0.8519 - val_loss: -0.9153 - val_iou: 0.8488
# Epoch 6/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9247 - iou: 0.8610 - val_loss: -0.9241 - val_iou: 0.8619
# Epoch 7/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9269 - iou: 0.8648 - val_loss: -0.9271 - val_iou: 0.8661
# Epoch 8/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9269 - iou: 0.8652 - val_loss: -0.9235 - val_iou: 0.8571
# Epoch 9/150
# 80/80 [==============================] - 2s 22ms/step - loss: -0.9267 - iou: 0.8653 - val_loss: -0.9229 - val_iou: 0.8603
# Epoch 10/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9304 - iou: 0.8706 - val_loss: -0.9290 - val_iou: 0.8681
# Epoch 11/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9299 - iou: 0.8699 - val_loss: -0.9279 - val_iou: 0.8668
# Epoch 12/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9329 - iou: 0.8749 - val_loss: -0.9268 - val_iou: 0.8667
# Epoch 13/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9082 - iou: 0.8349 - val_loss: -0.9225 - val_iou: 0.8567
# Epoch 14/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9266 - iou: 0.8647 - val_loss: -0.9330 - val_iou: 0.8744
# Epoch 15/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9311 - iou: 0.8723 - val_loss: -0.9241 - val_iou: 0.8587
# Epoch 16/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9335 - iou: 0.8760 - val_loss: -0.9312 - val_iou: 0.8743
# Epoch 17/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9345 - iou: 0.8777 - val_loss: -0.9321 - val_iou: 0.8716
# Epoch 18/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9337 - iou: 0.8762 - val_loss: -0.9349 - val_iou: 0.8776
# Epoch 19/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9358 - iou: 0.8806 - val_loss: -0.9372 - val_iou: 0.8794
# Epoch 20/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9375 - iou: 0.8831 - val_loss: -0.9385 - val_iou: 0.8837
# Epoch 21/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9377 - iou: 0.8836 - val_loss: -0.9404 - val_iou: 0.8840
# Epoch 22/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9417 - iou: 0.8904 - val_loss: -0.9403 - val_iou: 0.8862
# Epoch 23/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9384 - iou: 0.8850 - val_loss: -0.9416 - val_iou: 0.8876
# Epoch 24/150
# 80/80 [==============================] - 1s 17ms/step - loss: -0.9425 - iou: 0.8915 - val_loss: -0.9376 - val_iou: 0.8791
# Epoch 25/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9426 - iou: 0.8920 - val_loss: -0.9405 - val_iou: 0.8862
# Epoch 26/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9409 - iou: 0.8891 - val_loss: -0.9398 - val_iou: 0.8837
# Epoch 27/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9391 - iou: 0.8860 - val_loss: -0.9391 - val_iou: 0.8821
# Epoch 28/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9420 - iou: 0.8910 - val_loss: -0.9415 - val_iou: 0.8883
# Epoch 29/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9452 - iou: 0.8964 - val_loss: -0.9440 - val_iou: 0.8926
# Epoch 30/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9451 - iou: 0.8966 - val_loss: -0.9414 - val_iou: 0.8896
# Epoch 31/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9463 - iou: 0.8983 - val_loss: -0.9428 - val_iou: 0.8903
# Epoch 32/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9448 - iou: 0.8960 - val_loss: -0.9453 - val_iou: 0.8951
# Epoch 33/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9458 - iou: 0.8976 - val_loss: -0.9392 - val_iou: 0.8863
# Epoch 34/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9449 - iou: 0.8960 - val_loss: -0.9454 - val_iou: 0.8967
# Epoch 35/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9386 - iou: 0.8854 - val_loss: -0.9432 - val_iou: 0.8917
# Epoch 36/150
# 80/80 [==============================] - 1s 17ms/step - loss: -0.9437 - iou: 0.8942 - val_loss: -0.9448 - val_iou: 0.8936
# Epoch 37/150
# 80/80 [==============================] - 1s 18ms/step - loss: -0.9480 - iou: 0.9017 - val_loss: -0.9448 - val_iou: 0.8936
# Epoch 38/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9483 - iou: 0.9018 - val_loss: -0.9463 - val_iou: 0.8971
# Epoch 39/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9468 - iou: 0.8999 - val_loss: -0.9430 - val_iou: 0.8921
# Epoch 40/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9459 - iou: 0.8977 - val_loss: -0.9433 - val_iou: 0.8914
# Epoch 41/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9495 - iou: 0.9036 - val_loss: -0.9457 - val_iou: 0.8963
# Epoch 42/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9467 - iou: 0.8988 - val_loss: -0.9465 - val_iou: 0.8964
# Epoch 43/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9480 - iou: 0.9015 - val_loss: -0.9202 - val_iou: 0.8575
# Epoch 44/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9452 - iou: 0.8962 - val_loss: -0.9443 - val_iou: 0.8938
# Epoch 45/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9486 - iou: 0.9022 - val_loss: -0.9435 - val_iou: 0.8934
# Epoch 46/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9499 - iou: 0.9049 - val_loss: -0.9466 - val_iou: 0.8954
# Epoch 47/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9534 - iou: 0.9108 - val_loss: -0.9436 - val_iou: 0.8935
# Epoch 48/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9536 - iou: 0.9113 - val_loss: -0.9464 - val_iou: 0.8940
# Epoch 49/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9530 - iou: 0.9103 - val_loss: -0.9489 - val_iou: 0.9011
# Epoch 50/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9537 - iou: 0.9116 - val_loss: -0.9465 - val_iou: 0.8978
# Epoch 51/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9526 - iou: 0.9097 - val_loss: -0.9462 - val_iou: 0.8962
# Epoch 52/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9559 - iou: 0.9154 - val_loss: -0.9461 - val_iou: 0.8956
# Epoch 53/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9564 - iou: 0.9165 - val_loss: -0.9499 - val_iou: 0.9021
# Epoch 54/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9564 - iou: 0.9149 - val_loss: -0.9453 - val_iou: 0.8967
# Epoch 55/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9544 - iou: 0.9126 - val_loss: -0.9473 - val_iou: 0.8972
# Epoch 56/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9571 - iou: 0.9179 - val_loss: -0.9465 - val_iou: 0.8966
# Epoch 57/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9578 - iou: 0.9189 - val_loss: -0.9472 - val_iou: 0.8982
# Epoch 58/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9582 - iou: 0.9193 - val_loss: -0.9466 - val_iou: 0.8968
# Epoch 59/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9583 - iou: 0.9200 - val_loss: -0.9476 - val_iou: 0.8976
# Epoch 60/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9549 - iou: 0.9138 - val_loss: -0.9345 - val_iou: 0.8783
# Epoch 61/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9537 - iou: 0.9120 - val_loss: -0.9447 - val_iou: 0.8948
# Epoch 62/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9571 - iou: 0.9179 - val_loss: -0.9466 - val_iou: 0.8961
# Epoch 63/150
# 80/80 [==============================] - 1s 15ms/step - loss: -0.9548 - iou: 0.9139 - val_loss: -0.9479 - val_iou: 0.9003

# %%
plt.plot(resultsls.history['val_loss'])

# %%
plt.plot(resultsls.history['val_iou'])

# %%
plt.plot(resultsls.history['loss'])

# %%
plt.plot(resultsls.history['iou'])

# %%
cb = TimingCallback()

UNet_srs = UNet((96, 96, 3), activation_= SRS())
modelsrs = UNet_srs.buildModel()
UNet_srs.CompileandSummarize(modelsrs)
resultssrs = modells.fit(x = X_train, y = Y_train, batch_size = 8, epochs=150, callbacks = [cb, tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)], validation_data = (X_test, y_test))

training_inferences['SRS'] = sum(cb.logs)
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_9 (InputLayer)           [(None, 96, 96, 3)]  0           []
#
#  conv2d_152 (Conv2D)            (None, 96, 96, 16)   448         ['input_9[0][0]']
#
#  conv2d_153 (Conv2D)            (None, 96, 96, 16)   2320        ['conv2d_152[0][0]']
#
#  max_pooling2d_32 (MaxPooling2D  (None, 48, 48, 16)  0           ['conv2d_153[0][0]']
#  )
#
#  conv2d_154 (Conv2D)            (None, 48, 48, 32)   4640        ['max_pooling2d_32[0][0]']
#
#  conv2d_155 (Conv2D)            (None, 48, 48, 32)   9248        ['conv2d_154[0][0]']
#
#  max_pooling2d_33 (MaxPooling2D  (None, 24, 24, 32)  0           ['conv2d_155[0][0]']
#  )
#
#  conv2d_156 (Conv2D)            (None, 24, 24, 64)   18496       ['max_pooling2d_33[0][0]']
#
#  conv2d_157 (Conv2D)            (None, 24, 24, 64)   36928       ['conv2d_156[0][0]']
#
#  max_pooling2d_34 (MaxPooling2D  (None, 12, 12, 64)  0           ['conv2d_157[0][0]']
#  )
#
#  conv2d_158 (Conv2D)            (None, 12, 12, 128)  73856       ['max_pooling2d_34[0][0]']
#
#  conv2d_159 (Conv2D)            (None, 12, 12, 128)  147584      ['conv2d_158[0][0]']
#
#  max_pooling2d_35 (MaxPooling2D  (None, 6, 6, 128)   0           ['conv2d_159[0][0]']
#  )
#
#  conv2d_160 (Conv2D)            (None, 6, 6, 256)    295168      ['max_pooling2d_35[0][0]']
#
#  conv2d_161 (Conv2D)            (None, 6, 6, 256)    590080      ['conv2d_160[0][0]']
#
#  conv2d_transpose_32 (Conv2DTra  (None, 12, 12, 128)  131200     ['conv2d_161[0][0]']
#  nspose)
#
#  concatenate_32 (Concatenate)   (None, 12, 12, 256)  0           ['conv2d_transpose_32[0][0]',
#                                                                   'conv2d_159[0][0]']
#
#  conv2d_162 (Conv2D)            (None, 12, 12, 128)  295040      ['concatenate_32[0][0]']
#
#  conv2d_163 (Conv2D)            (None, 12, 12, 128)  147584      ['conv2d_162[0][0]']
#
#  conv2d_transpose_33 (Conv2DTra  (None, 24, 24, 64)  32832       ['conv2d_163[0][0]']
#  nspose)
#
#  concatenate_33 (Concatenate)   (None, 24, 24, 128)  0           ['conv2d_transpose_33[0][0]',
#                                                                   'conv2d_157[0][0]']
#
#  conv2d_164 (Conv2D)            (None, 24, 24, 64)   73792       ['concatenate_33[0][0]']
#
#  conv2d_165 (Conv2D)            (None, 24, 24, 64)   36928       ['conv2d_164[0][0]']
#
#  conv2d_transpose_34 (Conv2DTra  (None, 48, 48, 32)  8224        ['conv2d_165[0][0]']
#  nspose)
#
#  concatenate_34 (Concatenate)   (None, 48, 48, 64)   0           ['conv2d_transpose_34[0][0]',
#                                                                   'conv2d_155[0][0]']
#
#  conv2d_166 (Conv2D)            (None, 48, 48, 32)   18464       ['concatenate_34[0][0]']
#
#  conv2d_167 (Conv2D)            (None, 48, 48, 32)   9248        ['conv2d_166[0][0]']
#
#  conv2d_transpose_35 (Conv2DTra  (None, 96, 96, 16)  2064        ['conv2d_167[0][0]']
#  nspose)
#
#  concatenate_35 (Concatenate)   (None, 96, 96, 32)   0           ['conv2d_transpose_35[0][0]',
#                                                                   'conv2d_153[0][0]']
#
#  conv2d_168 (Conv2D)            (None, 96, 96, 16)   4624        ['concatenate_35[0][0]']
#
#  conv2d_169 (Conv2D)            (None, 96, 96, 16)   2320        ['conv2d_168[0][0]']
#
#  conv2d_170 (Conv2D)            (None, 96, 96, 1)    17          ['conv2d_169[0][0]']
#
# ==================================================================================================
# Total params: 1,941,105
# Trainable params: 1,941,105
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9582 - iou: 0.9199 - val_loss: -0.9472 - val_iou: 0.8978
# Epoch 2/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9587 - iou: 0.9206 - val_loss: -0.9479 - val_iou: 0.8987
# Epoch 3/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9588 - iou: 0.9210 - val_loss: -0.9462 - val_iou: 0.8965
# Epoch 4/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9597 - iou: 0.9218 - val_loss: -0.9486 - val_iou: 0.9007
# Epoch 5/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9598 - iou: 0.9228 - val_loss: -0.9475 - val_iou: 0.8989
# Epoch 6/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9613 - iou: 0.9257 - val_loss: -0.9483 - val_iou: 0.9009
# Epoch 7/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9616 - iou: 0.9260 - val_loss: -0.9462 - val_iou: 0.8963
# Epoch 8/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9624 - iou: 0.9276 - val_loss: -0.9488 - val_iou: 0.9008
# Epoch 9/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9590 - iou: 0.9215 - val_loss: -0.9452 - val_iou: 0.8956
# Epoch 10/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9595 - iou: 0.9219 - val_loss: -0.9464 - val_iou: 0.8960
# Epoch 11/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9600 - iou: 0.9232 - val_loss: -0.9480 - val_iou: 0.8989
# Epoch 12/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9599 - iou: 0.9230 - val_loss: -0.9473 - val_iou: 0.8972
# Epoch 13/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9626 - iou: 0.9279 - val_loss: -0.9470 - val_iou: 0.8977
# Epoch 14/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9623 - iou: 0.9273 - val_loss: -0.9497 - val_iou: 0.9015
# Epoch 15/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9627 - iou: 0.9281 - val_loss: -0.9483 - val_iou: 0.9002
# Epoch 16/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9635 - iou: 0.9294 - val_loss: -0.9469 - val_iou: 0.8962
# Epoch 17/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9635 - iou: 0.9296 - val_loss: -0.9479 - val_iou: 0.9003
# Epoch 18/150
# 80/80 [==============================] - 1s 16ms/step - loss: -0.9633 - iou: 0.9290 - val_loss: -0.9468 - val_iou: 0.8944
# Epoch 19/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9637 - iou: 0.9299 - val_loss: -0.9437 - val_iou: 0.8908
# Epoch 20/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9640 - iou: 0.9302 - val_loss: -0.9471 - val_iou: 0.8990
# Epoch 21/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9653 - iou: 0.9328 - val_loss: -0.9452 - val_iou: 0.8945
# Epoch 22/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9644 - iou: 0.9313 - val_loss: -0.9480 - val_iou: 0.9012
# Epoch 23/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9643 - iou: 0.9312 - val_loss: -0.9484 - val_iou: 0.8984
# Epoch 24/150
# 80/80 [==============================] - 1s 14ms/step - loss: -0.9648 - iou: 0.9319 - val_loss: -0.9472 - val_iou: 0.8962

# %%
plt.plot(resultssrs.history['val_loss'])

# %%
plt.plot(resultssrs.history['val_iou'])

# %%
plt.plot(resultssrs.history['loss'])

# %%
plt.plot(resultssrs.history['iou'])

# %%
training_inferences
# Out:
# {'MexicanReLU': 125.468850857,
#  'Swish': 82.74901054199927,
#  'TrainableLeakyReLU': 32.940766922000535,
#  'ISRU': 79.65041707999978,
#  'Mish': 65.7150443340006,
#  'gated_swish': 78.6331842549996,
#  'relu': 22.246085971999946,
#  'LearnableSwish': 75.78532325499987,
#  'SRS': 27.584539630999416}

# %%
x = []
y = []

for i in training_inferences:
    x.append(i)
    y.append(training_inferences[i])

# %%
#'Comparision of training times in different activation functions
fig, ax = plt.subplots()
plt.bar(range(len(y)), y, tick_label=x)
plt.xticks(rotation='vertical')
fig.tight_layout()
plt.show()
